# %%
import common
import importlib
from matplotlib.lines import Line2D
from matplotlib.patches import Patch
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import re
import socket
import plotting

import matplotlib.style
matplotlib.style.use('classic')

# Show all columns and rows in a dataframe
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


# Size of the axis overflow indicators
OVERFLOW_FONT_SIZE = 6

# %%
# graphalytics inserts
pers_experiments = "num_threads_read == 0 and (hostname == 'scyper22')"

data_ins = common.import_gfe("view_graphalytics_inserts").query(pers_experiments).copy() # data from the experiments
data_ins["build_frequency"].fillna(pd.Timedelta(0), inplace=True) # replace NaT with 0, otherwise the records are ignored in the group by

data_ins = data_ins.query("((block_size == 512) and library == 'sortledton.3') or library != 'sortledton.3'")

# graphalytics load
data_load = common.import_gfe("view_graphalytics_load").query(pers_experiments).copy()
# shape the dataframe as data_ins
data_load["build_frequency"] = pd.Timedelta(0)
data_load["build_frequency_secs"] = np.NaN
data_load["num_snapshots_created"] = 0
data_load["num_threads_write"] = 0
data_load["block_size"] = -1

data = pd.concat([data_ins, data_load])
data["validate_inserts"].fillna("0", inplace=True)
data["validate_output"].fillna("0", inplace=True)


data = data.query("validate_inserts == '0' and validate_output == '0'")

data = data.groupby(["library", "compiler_family", "graph", "build_frequency","num_threads_read", "num_threads_write", "algorithm"]) \
    .agg(completion_time=("median_secs", "median"), count=("median_secs", "count"), ct_std=("median_secs", "std"))
data["cov"] = data["ct_std"] / data["completion_time"]
data
# Out:
#                                                                                                                             completion_time  \
# library                        compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# baseline_v3                    gcc             dota-league    0 days 00:00:00 0                1                 bfs               7.538361
#                                                                                                                  cdlp             52.287221
#                                                                                                                  lcc            1882.367861
#                                                                                                                  pagerank         74.906913
#                                                                                                                  sssp              3.600868
#                                                                                                                  wcc              10.388922
#                                                graph500-24    0 days 00:00:00 0                1                 bfs             125.555598
#                                                                                                                  cdlp                   NaN
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank       1266.711086
#                                                                                                                  sssp             81.206667
#                                                                                                                  wcc             322.996458
#                                                uniform-24     0 days 00:00:00 0                1                 bfs             153.350156
#                                                                                                                  cdlp           1797.668647
#                                                                                                                  lcc             421.805360
#                                                                                                                  pagerank       1628.261105
#                                                                                                                  sssp            100.996033
#                                                                                                                  wcc             186.280122
# csr3                           gcc             com-friendster 0 days 00:00:00 0                0                 bfs               1.027292
#                                                                                                                  cdlp            160.783570
#                                                                                                                  lcc             835.651810
#                                                                                                                  pagerank         31.602786
#                                                                                                                  sssp             43.221247
#                                                                                                                  wcc              10.248647
#                                                dota-league    0 days 00:00:00 0                0                 bfs               0.000805
#                                                                                                                  cdlp              1.148272
#                                                                                                                  lcc             363.353080
#                                                                                                                  pagerank          0.137712
#                                                                                                                  sssp              0.402430
#                                                                                                                  wcc               0.029459
#                                                graph500-22    0 days 00:00:00 0                0                 bfs               0.036871
#                                                                                                                  cdlp              8.128233
#                                                                                                                  lcc             306.267269
#                                                                                                                  pagerank          0.409062
#                                                                                                                  sssp              0.861648
#                                                                                                                  wcc               0.158084
#                                                graph500-24    0 days 00:00:00 0                0                 bfs               0.137484
#                                                                                                                  cdlp             33.922899
#                                                                                                                  lcc            2236.280409
#                                                                                                                  pagerank          2.724284
#                                                                                                                  sssp              6.828722
#                                                                                                                  wcc               0.939615
#                                                graph500-26    0 days 00:00:00 0                0                 bfs               0.498458
#                                                                                                                  cdlp             70.469243
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank         15.265612
#                                                                                                                  sssp             31.582371
#                                                                                                                  wcc               4.959747
#                                                uniform-24     0 days 00:00:00 0                0                 bfs               0.147745
#                                                                                                                  cdlp             41.624740
#                                                                                                                  lcc              21.949081
#                                                                                                                  pagerank          3.410902
#                                                                                                                  sssp              7.146886
#                                                                                                                  wcc               1.183984
#                                                uniform-26     0 days 00:00:00 0                0                 bfs               0.572139
#                                                                                                                  cdlp            175.569887
#                                                                                                                  lcc              92.364151
#                                                                                                                  pagerank         18.648990
#                                                                                                                  sssp             36.968563
#                                                                                                                  wcc               6.251525
# csr3-lcc                       gcc             com-friendster 0 days 00:00:00 0                0                 bfs               0.987290
#                                                                                                                  cdlp            296.952842
#                                                                                                                  lcc              67.071760
#                                                                                                                  pagerank         31.766556
#                                                                                                                  sssp             53.552172
#                                                                                                                  wcc              10.134346
#                                                dota-league    0 days 00:00:00 0                0                 bfs               0.000832
#                                                                                                                  cdlp              1.130815
#                                                                                                                  lcc              54.222333
#                                                                                                                  pagerank          0.146841
#                                                                                                                  sssp              0.428904
#                                                                                                                  wcc               0.030136
#                                                graph500-22    0 days 00:00:00 0                0                 bfs               0.034255
#                                                                                                                  cdlp              8.039117
#                                                                                                                  lcc              12.347005
#                                                                                                                  pagerank          0.409781
#                                                                                                                  sssp              0.901464
#                                                                                                                  wcc               0.153195
#                                                graph500-24    0 days 00:00:00 0                0                 bfs               0.136920
#                                                                                                                  cdlp             32.441325
#                                                                                                                  lcc              80.472171
#                                                                                                                  pagerank          2.710109
#                                                                                                                  sssp              5.557368
#                                                                                                                  wcc               0.923030
#                                                graph500-26    0 days 00:00:00 0                0                 bfs               0.501221
#                                                                                                                  cdlp            104.740893
#                                                                                                                  lcc             569.605217
#                                                                                                                  pagerank         15.323130
#                                                                                                                  sssp             32.456623
#                                                                                                                  wcc               4.929197
#                                                uniform-24     0 days 00:00:00 0                0                 bfs               0.145892
#                                                                                                                  cdlp             24.325043
#                                                                                                                  lcc               2.925042
#                                                                                                                  pagerank          3.424995
#                                                                                                                  sssp              7.171131
#                                                                                                                  wcc               1.172135
#                                                uniform-26     0 days 00:00:00 0                0                 bfs               0.566363
#                                                                                                                  cdlp             98.890649
#                                                                                                                  lcc              13.866267
#                                                                                                                  pagerank         18.633433
#                                                                                                                  sssp             37.459210
#                                                                                                                  wcc               6.191338
# csr3-lcc-numa                  gcc             com-friendster 0 days 00:00:00 0                0                 bfs               0.970899
#                                                                                                                  cdlp            177.237292
#                                                                                                                  lcc              60.032766
#                                                                                                                  pagerank         31.227518
#                                                                                                                  sssp             59.441738
#                                                                                                                  wcc              10.068403
#                                                dota-league    0 days 00:00:00 0                0                 bfs               0.000727
#                                                                                                                  cdlp              1.171629
#                                                                                                                  lcc              53.648330
#                                                                                                                  pagerank          0.105036
#                                                                                                                  sssp              0.245215
#                                                                                                                  wcc               0.023842
#                                                graph500-22    0 days 00:00:00 0                0                 bfs               0.033258
#                                                                                                                  cdlp              8.122214
#                                                                                                                  lcc              11.931342
#                                                                                                                  pagerank          0.397270
#                                                                                                                  sssp              0.739230
#                                                                                                                  wcc               0.154064
#                                                graph500-24    0 days 00:00:00 0                0                 bfs               0.131544
#                                                                                                                  cdlp             14.926092
#                                                                                                                  lcc              72.086112
#                                                                                                                  pagerank          2.688269
#                                                                                                                  sssp              4.827259
#                                                                                                                  wcc               0.929016
#                                                graph500-26    0 days 00:00:00 0                0                 bfs               0.480766
#                                                                                                                  cdlp            140.942144
#                                                                                                                  lcc             478.273912
#                                                                                                                  pagerank         15.201051
#                                                                                                                  sssp             26.432848
#                                                                                                                  wcc               4.943431
#                                                uniform-24     0 days 00:00:00 0                0                 bfs               0.148202
#                                                                                                                  cdlp             23.132612
#                                                                                                                  lcc               2.816906
#                                                                                                                  pagerank          3.309615
#                                                                                                                  sssp              6.443192
#                                                                                                                  wcc               1.164549
#                                                uniform-26     0 days 00:00:00 0                0                 bfs               0.518993
#                                                                                                                  cdlp            180.167332
#                                                                                                                  lcc              13.111546
#                                                                                                                  pagerank         18.350899
#                                                                                                                  sssp             34.104711
#                                                                                                                  wcc               6.210624
# g1_v6-ref-ignore-build         gcc             dota-league    0 days 00:00:00 0                20                bfs               3.315888
#                                                                                                                  cdlp              4.690717
#                                                                                                                  lcc             556.099816
#                                                                                                                  pagerank          3.743046
#                                                                                                                  sssp              3.946425
#                                                                                                                  wcc               6.239842
#                                                graph500-22    0 days 00:00:00 0                20                bfs               3.372719
#                                                                                                                  cdlp              9.974392
#                                                                                                                  lcc             484.695291
#                                                                                                                  pagerank          4.325693
#                                                                                                                  sssp              5.323083
#                                                                                                                  wcc              13.924942
#                                                graph500-24    0 days 00:00:00 0                20                bfs               3.666789
#                                                                                                                  cdlp             31.449167
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          9.110301
#                                                                                                                  sssp             15.668837
#                                                                                                                  wcc              64.645621
#                                                graph500-26    0 days 00:00:00 0                20                bfs               5.189803
#                                                                                                                  cdlp            135.322500
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank         33.641130
#                                                                                                                  sssp             72.754567
#                                                                                                                  wcc             352.482678
#                                                uniform-24     0 days 00:00:00 0                20                bfs               3.728817
#                                                                                                                  cdlp             47.025972
#                                                                                                                  lcc              72.123853
#                                                                                                                  pagerank         11.348139
#                                                                                                                  sssp             21.650063
#                                                                                                                  wcc              90.251136
#                                                uniform-26     0 days 00:00:00 0                20                bfs               5.263770
#                                                                                                                  cdlp            186.268955
#                                                                                                                  lcc             338.458564
#                                                                                                                  pagerank         40.076869
#                                                                                                                  sssp             90.544796
#                                                                                                                  wcc             539.230175
# livegraph3_ro                  gcc             com-friendster 0 days 00:00:00 0                20                bfs               8.524041
#                                                                                                                  cdlp            290.855899
#                                                                                                                  lcc            1428.454927
#                                                                                                                  pagerank         73.268094
#                                                                                                                  sssp            109.375252
#                                                                                                                  wcc              30.448113
#                                                dota-league    0 days 00:00:00 0                20                bfs               0.057192
#                                                                                                                  cdlp              1.395516
#                                                                                                                  lcc             573.513740
#                                                                                                                  pagerank          0.476036
#                                                                                                                  sssp              0.824219
#                                                                                                                  wcc               0.090900
#                                                graph500-22    0 days 00:00:00 0                20                bfs               0.519948
#                                                                                                                  cdlp              6.935005
#                                                                                                                  lcc             493.041368
#                                                                                                                  pagerank          1.474466
#                                                                                                                  sssp              1.952101
#                                                                                                                  wcc               0.390946
#                                                graph500-24    0 days 00:00:00 0                20                bfs               2.150392
#                                                                                                                  cdlp             27.848318
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          7.009486
#                                                                                                                  sssp              8.998111
#                                                                                                                  wcc               1.671248
#                                                graph500-26    0 days 00:00:00 0                20                bfs               8.921137
#                                                                                                                  cdlp            115.255477
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank         34.549801
#                                                                                                                  sssp             57.409542
#                                                                                                                  wcc               7.407230
#                                                uniform-24     0 days 00:00:00 0                20                bfs               0.804347
#                                                                                                                  cdlp             42.654666
#                                                                                                                  lcc              38.357464
#                                                                                                                  pagerank          9.205213
#                                                                                                                  sssp             18.121702
#                                                                                                                  wcc               2.309004
#                                                uniform-26     0 days 00:00:00 0                20                bfs               3.155160
#                                                                                                                  cdlp            174.584802
#                                                                                                                  lcc             166.254569
#                                                                                                                  pagerank         42.051069
#                                                                                                                  sssp             90.646664
#                                                                                                                  wcc              10.087313
# llama8-ref                     gcc             dota-league    0 days 00:00:10 0                16                bfs               0.002966
#                                                                                                                  cdlp              2.401328
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          0.144010
#                                                                                                                  sssp              1.649414
#                                                                                                                  wcc               0.035468
#                                                graph500-22    0 days 00:00:00 0                16                bfs               0.044696
#                                                                                                                  cdlp              5.530655
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          0.365087
#                                                                                                                  sssp              2.665819
#                                                                                                                  wcc               0.137474
#                                                               0 days 00:00:10 0                16                bfs               0.044881
#                                                                                                                  cdlp              8.249646
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          0.433066
#                                                                                                                  sssp              3.452668
#                                                                                                                  wcc               0.143550
#                                                graph500-24    0 days 00:00:00 0                16                bfs               0.159036
#                                                                                                                  cdlp             21.477475
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          2.111017
#                                                                                                                  sssp             12.179139
#                                                                                                                  wcc               0.613714
#                                                               0 days 00:00:10 0                16                bfs               0.165804
#                                                                                                                  cdlp             30.885655
#                                                                                                                  pagerank          3.275807
#                                                                                                                  sssp             25.491201
#                                                                                                                  wcc               0.839498
#                                                uniform-24     0 days 00:00:00 0                16                bfs               0.165964
#                                                                                                                  cdlp             36.579861
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          4.500929
#                                                                                                                  sssp             17.595746
#                                                                                                                  wcc               1.175755
#                                                               0 days 00:00:10 0                16                bfs               0.212838
#                                                                                                                  cdlp             63.223419
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank          7.538110
#                                                                                                                  sssp             69.503388
#                                                                                                                  wcc               1.725500
# mb-csr.6                       gcc             com-friendster 0 days 00:00:00 0                56                bfs               3.798788
#                                                                                                                  cdlp            287.307148
#                                                                                                                  lcc             218.048387
#                                                                                                                  pagerank         65.158166
#                                                                                                                  sssp             73.338821
#                                                                                                                  wcc              45.294865
#                                                dota-league    0 days 00:00:00 0                56                bfs               0.004292
#                                                                                                                  cdlp              1.253532
#                                                                                                                  lcc             107.437410
#                                                                                                                  pagerank          0.243464
#                                                                                                                  sssp              0.493826
#                                                                                                                  wcc               0.107543
#                                                graph500-22    0 days 00:00:00 0                56                bfs               0.150570
#                                                                                                                  cdlp              4.185337
#                                                                                                                  lcc              22.516396
#                                                                                                                  pagerank          1.343167
#                                                                                                                  sssp              1.479605
#                                                                                                                  wcc               0.760865
#                                                graph500-24    0 days 00:00:00 0                56                bfs               0.542028
#                                                                                                                  cdlp             29.291488
#                                                                                                                  lcc             131.826943
#                                                                                                                  pagerank          5.622248
#                                                                                                                  sssp              6.513451
#                                                                                                                  wcc               3.190213
#                                                graph500-26    0 days 00:00:00 0                56                bfs               1.774992
#                                                                                                                  cdlp             89.797815
#                                                                                                                  lcc             779.362995
#                                                                                                                  pagerank         25.414916
#                                                                                                                  sssp             38.281106
#                                                                                                                  wcc              10.652522
#                                                uniform-24     0 days 00:00:00 0                56                bfs               0.344089
#                                                                                                                  cdlp             40.952292
#                                                                                                                  lcc              12.314545
#                                                                                                                  pagerank          8.042832
#                                                                                                                  sssp             13.995397
#                                                                                                                  wcc               3.114787
#                                                uniform-26     0 days 00:00:00 0                56                bfs               1.546083
#                                                                                                                  cdlp            178.011376
#                                                                                                                  lcc              53.424357
#                                                                                                                  pagerank         37.059872
#                                                                                                                  sssp             66.684629
#                                                                                                                  wcc              14.601343
# mb-csr.8                       gcc             com-friendster 0 days 00:00:00 0                56                bfs               1.125382
#                                                                                                                  cdlp            227.241485
#                                                                                                                  lcc              59.470150
#                                                                                                                  pagerank         30.603569
#                                                                                                                  sssp             49.037404
#                                                                                                                  wcc              16.095385
#                                                dota-league    0 days 00:00:00 0                56                bfs               0.000776
#                                                                                                                  cdlp              1.107514
#                                                                                                                  lcc              49.816105
#                                                                                                                  pagerank          0.140827
#                                                                                                                  sssp              0.404890
#                                                                                                                  wcc               0.029735
#                                                graph500-22    0 days 00:00:00 0                56                bfs               0.037814
#                                                                                                                  cdlp              3.703384
#                                                                                                                  lcc               8.417857
#                                                                                                                  pagerank          0.337325
#                                                                                                                  sssp              0.826469
#                                                                                                                  wcc               0.118526
#                                                graph500-24    0 days 00:00:00 0                56                bfs               0.139064
#                                                                                                                  cdlp             16.663601
#                                                                                                                  lcc              51.627964
#                                                                                                                  pagerank          1.786068
#                                                                                                                  sssp              4.717334
#                                                                                                                  wcc               0.576570
#                                                graph500-26    0 days 00:00:00 0                56                bfs               0.514324
#                                                                                                                  cdlp            119.647970
#                                                                                                                  lcc             309.646945
#                                                                                                                  pagerank         10.626454
# ...
#                                                                                                                  wcc             NaN
# sortledton.raw-access-bfs      gcc             dota-league    0 days 00:00:00 0                56                bfs        0.372284
#                                                                                                                  pagerank   0.052007
#                                                                                                                  wcc        0.012592
#                                                graph500-22    0 days 00:00:00 0                56                bfs        0.649253
#                                                                                                                  pagerank   0.066174
#                                                                                                                  wcc        0.056806
#                                                graph500-24    0 days 00:00:00 0                56                bfs        0.595132
#                                                                                                                  pagerank   0.010543
#                                                                                                                  wcc        0.029795
# stinger7-ref                   gcc             dota-league    0 days 00:00:00 0                56                bfs        0.006050
#                                                                                                                  cdlp       0.020389
#                                                                                                                  lcc        0.002404
#                                                                                                                  pagerank   0.006013
#                                                                                                                  sssp       0.008668
#                                                                                                                  wcc        0.007452
#                                                graph500-22    0 days 00:00:00 0                56                bfs        0.012442
#                                                                                                                  cdlp       0.046542
#                                                                                                                  lcc        0.005250
#                                                                                                                  pagerank   0.011713
#                                                                                                                  sssp       0.029457
#                                                                                                                  wcc        0.083468
#                                                graph500-24    0 days 00:00:00 0                56                bfs        0.011474
#                                                                                                                  cdlp       0.036857
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank   0.005190
#                                                                                                                  sssp       0.008001
#                                                                                                                  wcc        0.022990
#                                                uniform-24     0 days 00:00:00 0                56                bfs        0.008653
#                                                                                                                  cdlp       0.078213
#                                                                                                                  lcc        0.006877
#                                                                                                                  pagerank   0.007015
#                                                                                                                  sssp       0.005240
#                                                                                                                  wcc        0.027282
# teseo-lcc-dv.12b               gcc             com-friendster 0 days 00:00:00 0                56                bfs        0.290316
#                                                                                                                  cdlp       0.052039
#                                                                                                                  lcc        0.002446
#                                                                                                                  pagerank   0.032525
#                                                                                                                  sssp       0.013252
#                                                                                                                  wcc        0.221898
#                                                dota-league    0 days 00:00:00 0                56                bfs        0.694200
#                                                                                                                  cdlp       0.037579
#                                                                                                                  lcc        0.011342
#                                                                                                                  pagerank   0.065288
#                                                                                                                  sssp       0.011308
#                                                                                                                  wcc        0.027254
#                                                graph500-22    0 days 00:00:00 0                56                bfs        0.164334
#                                                                                                                  cdlp       0.072948
#                                                                                                                  lcc        0.026507
#                                                                                                                  pagerank   0.035734
#                                                                                                                  sssp       0.030254
#                                                                                                                  wcc        0.085301
#                                                graph500-24    0 days 00:00:00 0                56                bfs        0.162963
#                                                                                                                  cdlp       0.051681
#                                                                                                                  lcc        0.004009
#                                                                                                                  pagerank   0.015792
#                                                                                                                  sssp       0.009325
#                                                                                                                  wcc        0.132072
#                                                graph500-26    0 days 00:00:00 0                56                bfs        0.270372
#                                                                                                                  cdlp       0.025616
#                                                                                                                  lcc        0.004273
#                                                                                                                  pagerank   0.010108
#                                                                                                                  sssp       0.016660
#                                                                                                                  wcc        0.025329
#                                                uniform-24     0 days 00:00:00 0                56                bfs        0.016981
#                                                                                                                  cdlp       0.025741
#                                                                                                                  lcc        0.003004
#                                                                                                                  pagerank   0.035691
#                                                                                                                  sssp       0.007623
#                                                                                                                  wcc        0.018489
#                                                uniform-26     0 days 00:00:00 0                56                bfs        0.023848
#                                                                                                                  cdlp       0.007732
#                                                                                                                  lcc        0.003908
#                                                                                                                  pagerank   0.038301
#                                                                                                                  sssp       0.010599
#                                                                                                                  wcc        0.015095
# teseo-lcc.12                   gcc             com-friendster 0 days 00:00:00 0                56                bfs        0.213880
#                                                                                                                  cdlp       0.030587
#                                                                                                                  lcc        0.011780
#                                                                                                                  pagerank   0.003459
#                                                                                                                  sssp       0.008049
#                                                                                                                  wcc        0.013765
#                                                dota-league    0 days 00:00:00 0                56                bfs        0.660541
#                                                                                                                  cdlp       0.015234
#                                                                                                                  lcc        0.010478
#                                                                                                                  pagerank   0.024449
#                                                                                                                  sssp       0.018897
#                                                                                                                  wcc        0.024373
#                                                graph500-22    0 days 00:00:00 0                56                bfs        0.286489
#                                                                                                                  cdlp       0.034879
#                                                                                                                  lcc        0.036177
#                                                                                                                  pagerank   0.015777
#                                                                                                                  sssp       0.037229
#                                                                                                                  wcc        0.036081
#                                                graph500-24    0 days 00:00:00 0                56                bfs        0.170301
#                                                                                                                  cdlp       0.036940
#                                                                                                                  lcc        0.023524
#                                                                                                                  pagerank   0.006213
#                                                                                                                  sssp       0.011362
#                                                                                                                  wcc        0.029864
#                                                graph500-26    0 days 00:00:00 0                56                bfs        0.223514
#                                                                                                                  cdlp       0.009490
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank   0.005499
#                                                                                                                  sssp       0.017101
#                                                                                                                  wcc        0.107299
#                                                uniform-24     0 days 00:00:00 0                56                bfs        0.194369
#                                                                                                                  cdlp       0.015422
#                                                                                                                  lcc        0.011362
#                                                                                                                  pagerank   0.010825
#                                                                                                                  sssp       0.009795
#                                                                                                                  wcc        0.030150
#                                                uniform-26     0 days 00:00:00 0                56                bfs        0.013255
#                                                                                                                  cdlp       0.006216
#                                                                                                                  lcc        0.004763
#                                                                                                                  pagerank   0.005343
#                                                                                                                  sssp       0.013921
#                                                                                                                  wcc        0.014900

# %%
data_csr = data

# %%
data_high_err = data.query("cov > 0.1")
data_high_err
# Out:
#                                                                                                                        completion_time  \
# library                   compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3-lcc                  gcc             com-friendster 0 days 00:00:00 0                0                 cdlp            296.952842
#                                                                                                             sssp             53.552172
#                                           graph500-22    0 days 00:00:00 0                0                 sssp              0.901464
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp             32.441325
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp            104.740893
#                                                                                                             sssp             32.456623
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp             24.325043
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp             98.890649
# csr3-lcc-numa             gcc             com-friendster 0 days 00:00:00 0                0                 cdlp            177.237292
#                                                                                                             sssp             59.441738
#                                           dota-league    0 days 00:00:00 0                0                 bfs               0.000727
#                                           graph500-22    0 days 00:00:00 0                0                 cdlp              8.122214
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp             14.926092
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp            140.942144
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp             23.132612
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp            180.167332
# g1_v6-ref-ignore-build    gcc             graph500-22    0 days 00:00:00 0                20                cdlp              9.974392
#                                           graph500-24    0 days 00:00:00 0                20                cdlp             31.449167
#                                           graph500-26    0 days 00:00:00 0                20                bfs               5.189803
#                                                                                                             cdlp            135.322500
#                                           uniform-24     0 days 00:00:00 0                20                cdlp             47.025972
#                                           uniform-26     0 days 00:00:00 0                20                cdlp            186.268955
#                                                                                                             wcc             539.230175
# livegraph3_ro             gcc             com-friendster 0 days 00:00:00 0                20                cdlp            290.855899
#                                           graph500-22    0 days 00:00:00 0                20                cdlp              6.935005
#                                                                                                             wcc               0.390946
#                                           graph500-24    0 days 00:00:00 0                20                cdlp             27.848318
#                                           uniform-24     0 days 00:00:00 0                20                cdlp             42.654666
#                                           uniform-26     0 days 00:00:00 0                20                cdlp            174.584802
# llama8-ref                gcc             dota-league    0 days 00:00:10 0                16                bfs               0.002966
#                                                                                                             cdlp              2.401328
#                                           graph500-22    0 days 00:00:10 0                16                cdlp              8.249646
#                                           graph500-24    0 days 00:00:10 0                16                cdlp             30.885655
#                                                                                                             wcc               0.839498
#                                           uniform-24     0 days 00:00:10 0                16                cdlp             63.223419
# mb-csr.6                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp            287.307148
#                                                                                                             wcc              45.294865
#                                           graph500-22    0 days 00:00:00 0                56                cdlp              4.185337
#                                                                                                             wcc               0.760865
#                                           graph500-24    0 days 00:00:00 0                56                cdlp             29.291488
#                                                                                                             wcc               3.190213
#                                           graph500-26    0 days 00:00:00 0                56                cdlp             89.797815
#                                                                                                             wcc              10.652522
#                                           uniform-24     0 days 00:00:00 0                56                cdlp             40.952292
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            178.011376
#                                                                                                             sssp             66.684629
#                                                                                                             wcc              14.601343
# mb-csr.8                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp            227.241485
#                                                                                                             sssp             49.037404
#                                           graph500-22    0 days 00:00:00 0                56                cdlp              3.703384
#                                           graph500-24    0 days 00:00:00 0                56                cdlp             16.663601
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            132.497073
# sortledton                gcc             com-friendster 0 days 00:00:00 0                56                cdlp            267.436107
#                                           graph500-22    0 days 00:00:00 0                56                cdlp              4.884318
#                                                                                                             pagerank          0.448248
#                                                                                                             sssp              1.307318
#                                                                                                             wcc               0.136441
#                                           graph500-26    0 days 00:00:00 0                56                cdlp            112.375749
#                                           uniform-24     0 days 00:00:00 0                56                cdlp             29.025987
#                                                                                                             wcc               1.049851
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            141.319805
#                                                                                                             wcc               6.945612
# sortledton.1              gcc             com-friendster 0 days 00:00:00 0                56                cdlp            321.215246
#                                           dota-league    0 days 00:00:00 0                56                bfs               0.003482
#                                           graph500-22    0 days 00:00:00 0                56                cdlp              5.123496
#                                           graph500-24    0 days 00:00:00 0                56                cdlp             32.897589
#                                           graph500-26    0 days 00:00:00 0                56                cdlp            146.673093
#                                           uniform-24     0 days 00:00:00 0                56                cdlp             41.752513
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            148.820877
#                                                                                                             wcc               8.048062
# sortledton.2              gcc             com-friendster 0 days 00:00:00 0                56                bfs               4.848868
#                                                                                                             cdlp            338.518186
#                                           dota-league    0 days 00:00:00 0                56                bfs               0.003629
#                                           graph500-22    0 days 00:00:00 0                56                bfs               0.170520
#                                                                                                             cdlp              4.787530
#                                           graph500-24    0 days 00:00:00 0                56                bfs               0.474530
#                                                                                                             cdlp             32.092599
#                                           graph500-26    0 days 00:00:00 0                56                bfs               2.210000
#                                                                                                             cdlp            148.782017
#                                           uniform-24     0 days 00:00:00 0                56                cdlp             42.606590
#                                                                                                             wcc               1.053868
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            144.745415
#                                                                                                             wcc               8.034015
# sortledton.3              gcc             com-friendster 0 days 00:00:00 0                56                cdlp            260.627118
#                                           graph500-22    0 days 00:00:00 0                56                cdlp              7.326248
#                                           graph500-24    0 days 00:00:00 0                56                cdlp             22.552226
#                                           uniform-24     0 days 00:00:00 0                56                cdlp             43.936870
#                                           uniform-26     0 days 00:00:00 0                56                cdlp            173.083578
#                                                                                                             wcc               5.534944
# sortledton.raw-access-bfs gcc             dota-league    0 days 00:00:00 0                56                bfs               0.024439
#                                           graph500-22    0 days 00:00:00 0                56                bfs               0.134608
#                                           graph500-24    0 days 00:00:00 0                56                bfs               0.833700
# teseo-lcc-dv.12b          gcc             com-friendster 0 days 00:00:00 0                56                bfs               0.988311
#                                                                                                             wcc               7.984816
#                                           dota-league    0 days 00:00:00 0                56                bfs               0.009959
#                                           graph500-22    0 days 00:00:00 0                56                bfs               0.059112
#                                           graph500-24    0 days 00:00:00 0                56                bfs               0.206834
#                                                                                                             wcc               0.879131
#                                           graph500-26    0 days 00:00:00 0                56                bfs               0.407783
# teseo-lcc.12              gcc             com-friendster 0 days 00:00:00 0                56                bfs               1.436367
#                                           dota-league    0 days 00:00:00 0                56                bfs               0.010583
#                                           graph500-22    0 days 00:00:00 0                56                bfs               0.051867
#                                           graph500-24    0 days 00:00:00 0                56                bfs               0.177329
#                                           graph500-26    0 days 00:00:00 0                56                bfs               0.578424
#                                                                                                             wcc              18.733884
#                                           uniform-24     0 days 00:00:00 0                56                bfs               0.141978
#
#                                                                                                                        count  \
# library                   compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3-lcc                  gcc             com-friendster 0 days 00:00:00 0                0                 cdlp           4
#                                                                                                             sssp           4
#                                           graph500-22    0 days 00:00:00 0                0                 sssp           5
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp           5
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp           4
#                                                                                                             sssp           4
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp           5
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp           3
# csr3-lcc-numa             gcc             com-friendster 0 days 00:00:00 0                0                 cdlp           5
#                                                                                                             sssp           5
#                                           dota-league    0 days 00:00:00 0                0                 bfs            5
#                                           graph500-22    0 days 00:00:00 0                0                 cdlp           5
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp           5
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp           5
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp           5
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp           5
# g1_v6-ref-ignore-build    gcc             graph500-22    0 days 00:00:00 0                20                cdlp           7
#                                           graph500-24    0 days 00:00:00 0                20                cdlp           7
#                                           graph500-26    0 days 00:00:00 0                20                bfs            5
#                                                                                                             cdlp           5
#                                           uniform-24     0 days 00:00:00 0                20                cdlp           7
#                                           uniform-26     0 days 00:00:00 0                20                cdlp           6
#                                                                                                             wcc            6
# livegraph3_ro             gcc             com-friendster 0 days 00:00:00 0                20                cdlp           6
#                                           graph500-22    0 days 00:00:00 0                20                cdlp           7
#                                                                                                             wcc            7
#                                           graph500-24    0 days 00:00:00 0                20                cdlp           7
#                                           uniform-24     0 days 00:00:00 0                20                cdlp           7
#                                           uniform-26     0 days 00:00:00 0                20                cdlp           5
# llama8-ref                gcc             dota-league    0 days 00:00:10 0                16                bfs            8
#                                                                                                             cdlp           8
#                                           graph500-22    0 days 00:00:10 0                16                cdlp           7
#                                           graph500-24    0 days 00:00:10 0                16                cdlp           7
#                                                                                                             wcc            7
#                                           uniform-24     0 days 00:00:10 0                16                cdlp           7
# mb-csr.6                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp           6
#                                                                                                             wcc            6
#                                           graph500-22    0 days 00:00:00 0                56                cdlp           6
#                                                                                                             wcc            6
#                                           graph500-24    0 days 00:00:00 0                56                cdlp           6
#                                                                                                             wcc            6
#                                           graph500-26    0 days 00:00:00 0                56                cdlp           6
#                                                                                                             wcc            6
#                                           uniform-24     0 days 00:00:00 0                56                cdlp           6
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           6
#                                                                                                             sssp           6
#                                                                                                             wcc            6
# mb-csr.8                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp           2
#                                                                                                             sssp           2
#                                           graph500-22    0 days 00:00:00 0                56                cdlp           3
#                                           graph500-24    0 days 00:00:00 0                56                cdlp           3
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           2
# sortledton                gcc             com-friendster 0 days 00:00:00 0                56                cdlp           4
#                                           graph500-22    0 days 00:00:00 0                56                cdlp          13
#                                                                                                             pagerank      13
#                                                                                                             sssp          13
#                                                                                                             wcc           13
#                                           graph500-26    0 days 00:00:00 0                56                cdlp           9
#                                           uniform-24     0 days 00:00:00 0                56                cdlp           8
#                                                                                                             wcc            8
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           4
#                                                                                                             wcc            4
# sortledton.1              gcc             com-friendster 0 days 00:00:00 0                56                cdlp           5
#                                           dota-league    0 days 00:00:00 0                56                bfs            5
#                                           graph500-22    0 days 00:00:00 0                56                cdlp           5
#                                           graph500-24    0 days 00:00:00 0                56                cdlp           5
#                                           graph500-26    0 days 00:00:00 0                56                cdlp           5
#                                           uniform-24     0 days 00:00:00 0                56                cdlp           5
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           5
#                                                                                                             wcc            5
# sortledton.2              gcc             com-friendster 0 days 00:00:00 0                56                bfs            5
#                                                                                                             cdlp           5
#                                           dota-league    0 days 00:00:00 0                56                bfs            5
#                                           graph500-22    0 days 00:00:00 0                56                bfs            5
#                                                                                                             cdlp           5
#                                           graph500-24    0 days 00:00:00 0                56                bfs            5
#                                                                                                             cdlp           5
#                                           graph500-26    0 days 00:00:00 0                56                bfs            5
#                                                                                                             cdlp           5
#                                           uniform-24     0 days 00:00:00 0                56                cdlp           5
#                                                                                                             wcc            5
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           5
#                                                                                                             wcc            5
# sortledton.3              gcc             com-friendster 0 days 00:00:00 0                56                cdlp           6
#                                           graph500-22    0 days 00:00:00 0                56                cdlp           6
#                                           graph500-24    0 days 00:00:00 0                56                cdlp           6
#                                           uniform-24     0 days 00:00:00 0                56                cdlp           6
#                                           uniform-26     0 days 00:00:00 0                56                cdlp           6
#                                                                                                             wcc            6
# sortledton.raw-access-bfs gcc             dota-league    0 days 00:00:00 0                56                bfs            5
#                                           graph500-22    0 days 00:00:00 0                56                bfs           14
#                                           graph500-24    0 days 00:00:00 0                56                bfs            4
# teseo-lcc-dv.12b          gcc             com-friendster 0 days 00:00:00 0                56                bfs            5
#                                                                                                             wcc            5
#                                           dota-league    0 days 00:00:00 0                56                bfs            8
#                                           graph500-22    0 days 00:00:00 0                56                bfs            6
#                                           graph500-24    0 days 00:00:00 0                56                bfs            7
#                                                                                                             wcc            7
#                                           graph500-26    0 days 00:00:00 0                56                bfs            5
# teseo-lcc.12              gcc             com-friendster 0 days 00:00:00 0                56                bfs            7
#                                           dota-league    0 days 00:00:00 0                56                bfs            7
#                                           graph500-22    0 days 00:00:00 0                56                bfs            7
#                                           graph500-24    0 days 00:00:00 0                56                bfs            7
#                                           graph500-26    0 days 00:00:00 0                56                bfs            5
#                                                                                                             wcc            5
#                                           uniform-24     0 days 00:00:00 0                56                bfs            7
#
#                                                                                                                            ct_std  \
# library                   compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3-lcc                  gcc             com-friendster 0 days 00:00:00 0                0                 cdlp        63.934555
#                                                                                                             sssp         8.474015
#                                           graph500-22    0 days 00:00:00 0                0                 sssp         0.136621
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp         8.670661
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp        43.767062
#                                                                                                             sssp         5.782345
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp         8.269963
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp        42.525480
# csr3-lcc-numa             gcc             com-friendster 0 days 00:00:00 0                0                 cdlp        63.569286
#                                                                                                             sssp         6.450456
#                                           dota-league    0 days 00:00:00 0                0                 bfs          0.000719
#                                           graph500-22    0 days 00:00:00 0                0                 cdlp         2.249751
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp         9.751065
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp        43.753290
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp         9.583719
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp        37.862413
# g1_v6-ref-ignore-build    gcc             graph500-22    0 days 00:00:00 0                20                cdlp         1.489115
#                                           graph500-24    0 days 00:00:00 0                20                cdlp         3.579686
#                                           graph500-26    0 days 00:00:00 0                20                bfs          0.843208
#                                                                                                             cdlp        19.685513
#                                           uniform-24     0 days 00:00:00 0                20                cdlp         5.986040
#                                           uniform-26     0 days 00:00:00 0                20                cdlp        34.378832
#                                                                                                             wcc        109.519579
# livegraph3_ro             gcc             com-friendster 0 days 00:00:00 0                20                cdlp        43.769149
#                                           graph500-22    0 days 00:00:00 0                20                cdlp         1.772951
#                                                                                                             wcc          0.044867
#                                           graph500-24    0 days 00:00:00 0                20                cdlp         4.561425
#                                           uniform-24     0 days 00:00:00 0                20                cdlp         9.236510
#                                           uniform-26     0 days 00:00:00 0                20                cdlp        26.254807
# llama8-ref                gcc             dota-league    0 days 00:00:10 0                16                bfs          0.000640
#                                                                                                             cdlp         0.573329
#                                           graph500-22    0 days 00:00:10 0                16                cdlp         0.879388
#                                           graph500-24    0 days 00:00:10 0                16                cdlp         6.124953
#                                                                                                             wcc          0.158566
#                                           uniform-24     0 days 00:00:10 0                16                cdlp        22.368314
# mb-csr.6                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp        47.080905
#                                                                                                             wcc          5.183879
#                                           graph500-22    0 days 00:00:00 0                56                cdlp         1.473643
#                                                                                                             wcc          0.234873
#                                           graph500-24    0 days 00:00:00 0                56                cdlp         5.560230
#                                                                                                             wcc          0.847620
#                                           graph500-26    0 days 00:00:00 0                56                cdlp        16.533071
#                                                                                                             wcc          3.526740
#                                           uniform-24     0 days 00:00:00 0                56                cdlp         7.308261
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        37.706460
#                                                                                                             sssp         9.692508
#                                                                                                             wcc          2.547447
# mb-csr.8                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp        69.266765
#                                                                                                             sssp         6.106018
#                                           graph500-22    0 days 00:00:00 0                56                cdlp         1.356020
#                                           graph500-24    0 days 00:00:00 0                56                cdlp         5.284524
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        48.562832
# sortledton                gcc             com-friendster 0 days 00:00:00 0                56                cdlp        45.872307
#                                           graph500-22    0 days 00:00:00 0                56                cdlp         1.308054
#                                                                                                             pagerank     0.404536
#                                                                                                             sssp         0.752382
#                                                                                                             wcc          0.119074
#                                           graph500-26    0 days 00:00:00 0                56                cdlp        22.397706
#                                           uniform-24     0 days 00:00:00 0                56                cdlp         8.098788
#                                                                                                             wcc          0.164808
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        27.480372
#                                                                                                             wcc          1.526838
# sortledton.1              gcc             com-friendster 0 days 00:00:00 0                56                cdlp        55.603788
#                                           dota-league    0 days 00:00:00 0                56                bfs          0.000875
#                                           graph500-22    0 days 00:00:00 0                56                cdlp         1.438341
#                                           graph500-24    0 days 00:00:00 0                56                cdlp         6.331162
#                                           graph500-26    0 days 00:00:00 0                56                cdlp        22.836758
#                                           uniform-24     0 days 00:00:00 0                56                cdlp        11.339619
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        35.117089
#                                                                                                             wcc          1.383692
# sortledton.2              gcc             com-friendster 0 days 00:00:00 0                56                bfs          0.699089
#                                                                                                             cdlp        55.966685
#                                           dota-league    0 days 00:00:00 0                56                bfs          0.000442
#                                           graph500-22    0 days 00:00:00 0                56                bfs          0.021561
#                                                                                                             cdlp         1.831150
#                                           graph500-24    0 days 00:00:00 0                56                bfs          0.074566
#                                                                                                             cdlp         5.278425
#                                           graph500-26    0 days 00:00:00 0                56                bfs          0.299860
#                                                                                                             cdlp        21.759633
#                                           uniform-24     0 days 00:00:00 0                56                cdlp        10.942113
#                                                                                                             wcc          0.219785
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        24.852734
#                                                                                                             wcc          1.370839
# sortledton.3              gcc             com-friendster 0 days 00:00:00 0                56                cdlp        47.851106
#                                           graph500-22    0 days 00:00:00 0                56                cdlp         1.133609
#                                           graph500-24    0 days 00:00:00 0                56                cdlp         4.850025
#                                           uniform-24     0 days 00:00:00 0                56                cdlp         9.631387
#                                           uniform-26     0 days 00:00:00 0                56                cdlp        31.792815
#                                                                                                             wcc          1.075527
# sortledton.raw-access-bfs gcc             dota-league    0 days 00:00:00 0                56                bfs          0.009098
#                                           graph500-22    0 days 00:00:00 0                56                bfs          0.087395
#                                           graph500-24    0 days 00:00:00 0                56                bfs          0.496161
# teseo-lcc-dv.12b          gcc             com-friendster 0 days 00:00:00 0                56                bfs          0.286922
#                                                                                                             wcc          1.771815
#                                           dota-league    0 days 00:00:00 0                56                bfs          0.006914
#                                           graph500-22    0 days 00:00:00 0                56                bfs          0.009714
#                                           graph500-24    0 days 00:00:00 0                56                bfs          0.033706
#                                                                                                             wcc          0.116109
#                                           graph500-26    0 days 00:00:00 0                56                bfs          0.110253
# teseo-lcc.12              gcc             com-friendster 0 days 00:00:00 0                56                bfs          0.307210
#                                           dota-league    0 days 00:00:00 0                56                bfs          0.006991
#                                           graph500-22    0 days 00:00:00 0                56                bfs          0.014859
#                                           graph500-24    0 days 00:00:00 0                56                bfs          0.030199
#                                           graph500-26    0 days 00:00:00 0                56                bfs          0.129286
#                                                                                                             wcc          2.010135
#                                           uniform-24     0 days 00:00:00 0                56                bfs          0.027596
#
#                                                                                                                             cov
# library                   compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3-lcc                  gcc             com-friendster 0 days 00:00:00 0                0                 cdlp       0.215302
#                                                                                                             sssp       0.158238
#                                           graph500-22    0 days 00:00:00 0                0                 sssp       0.151555
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp       0.267272
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp       0.417860
#                                                                                                             sssp       0.178156
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp       0.339977
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp       0.430025
# csr3-lcc-numa             gcc             com-friendster 0 days 00:00:00 0                0                 cdlp       0.358668
#                                                                                                             sssp       0.108517
#                                           dota-league    0 days 00:00:00 0                0                 bfs        0.988482
#                                           graph500-22    0 days 00:00:00 0                0                 cdlp       0.276987
#                                           graph500-24    0 days 00:00:00 0                0                 cdlp       0.653290
#                                           graph500-26    0 days 00:00:00 0                0                 cdlp       0.310434
#                                           uniform-24     0 days 00:00:00 0                0                 cdlp       0.414295
#                                           uniform-26     0 days 00:00:00 0                0                 cdlp       0.210151
# g1_v6-ref-ignore-build    gcc             graph500-22    0 days 00:00:00 0                20                cdlp       0.149294
#                                           graph500-24    0 days 00:00:00 0                20                cdlp       0.113825
#                                           graph500-26    0 days 00:00:00 0                20                bfs        0.162474
#                                                                                                             cdlp       0.145471
#                                           uniform-24     0 days 00:00:00 0                20                cdlp       0.127292
#                                           uniform-26     0 days 00:00:00 0                20                cdlp       0.184566
#                                                                                                             wcc        0.203104
# livegraph3_ro             gcc             com-friendster 0 days 00:00:00 0                20                cdlp       0.150484
#                                           graph500-22    0 days 00:00:00 0                20                cdlp       0.255653
#                                                                                                             wcc        0.114766
#                                           graph500-24    0 days 00:00:00 0                20                cdlp       0.163795
#                                           uniform-24     0 days 00:00:00 0                20                cdlp       0.216542
#                                           uniform-26     0 days 00:00:00 0                20                cdlp       0.150384
# llama8-ref                gcc             dota-league    0 days 00:00:10 0                16                bfs        0.215726
#                                                                                                             cdlp       0.238755
#                                           graph500-22    0 days 00:00:10 0                16                cdlp       0.106597
#                                           graph500-24    0 days 00:00:10 0                16                cdlp       0.198311
#                                                                                                             wcc        0.188882
#                                           uniform-24     0 days 00:00:10 0                16                cdlp       0.353798
# mb-csr.6                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp       0.163870
#                                                                                                             wcc        0.114447
#                                           graph500-22    0 days 00:00:00 0                56                cdlp       0.352097
#                                                                                                             wcc        0.308692
#                                           graph500-24    0 days 00:00:00 0                56                cdlp       0.189824
#                                                                                                             wcc        0.265694
#                                           graph500-26    0 days 00:00:00 0                56                cdlp       0.184114
#                                                                                                             wcc        0.331071
#                                           uniform-24     0 days 00:00:00 0                56                cdlp       0.178458
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.211821
#                                                                                                             sssp       0.145348
#                                                                                                             wcc        0.174467
# mb-csr.8                  gcc             com-friendster 0 days 00:00:00 0                56                cdlp       0.304816
#                                                                                                             sssp       0.124518
#                                           graph500-22    0 days 00:00:00 0                56                cdlp       0.366157
#                                           graph500-24    0 days 00:00:00 0                56                cdlp       0.317130
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.366520
# sortledton                gcc             com-friendster 0 days 00:00:00 0                56                cdlp       0.171526
#                                           graph500-22    0 days 00:00:00 0                56                cdlp       0.267807
#                                                                                                             pagerank   0.902483
#                                                                                                             sssp       0.575516
#                                                                                                             wcc        0.872714
#                                           graph500-26    0 days 00:00:00 0                56                cdlp       0.199311
#                                           uniform-24     0 days 00:00:00 0                56                cdlp       0.279019
#                                                                                                             wcc        0.156982
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.194455
#                                                                                                             wcc        0.219828
# sortledton.1              gcc             com-friendster 0 days 00:00:00 0                56                cdlp       0.173104
#                                           dota-league    0 days 00:00:00 0                56                bfs        0.251399
#                                           graph500-22    0 days 00:00:00 0                56                cdlp       0.280734
#                                           graph500-24    0 days 00:00:00 0                56                cdlp       0.192451
#                                           graph500-26    0 days 00:00:00 0                56                cdlp       0.155698
#                                           uniform-24     0 days 00:00:00 0                56                cdlp       0.271591
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.235969
#                                                                                                             wcc        0.171929
# sortledton.2              gcc             com-friendster 0 days 00:00:00 0                56                bfs        0.144176
#                                                                                                             cdlp       0.165328
#                                           dota-league    0 days 00:00:00 0                56                bfs        0.121660
#                                           graph500-22    0 days 00:00:00 0                56                bfs        0.126445
#                                                                                                             cdlp       0.382483
#                                           graph500-24    0 days 00:00:00 0                56                bfs        0.157137
#                                                                                                             cdlp       0.164475
#                                           graph500-26    0 days 00:00:00 0                56                bfs        0.135683
#                                                                                                             cdlp       0.146252
#                                           uniform-24     0 days 00:00:00 0                56                cdlp       0.256817
#                                                                                                             wcc        0.208551
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.171700
#                                                                                                             wcc        0.170629
# sortledton.3              gcc             com-friendster 0 days 00:00:00 0                56                cdlp       0.183600
#                                           graph500-22    0 days 00:00:00 0                56                cdlp       0.154732
#                                           graph500-24    0 days 00:00:00 0                56                cdlp       0.215057
#                                           uniform-24     0 days 00:00:00 0                56                cdlp       0.219210
#                                           uniform-26     0 days 00:00:00 0                56                cdlp       0.183685
#                                                                                                             wcc        0.194316
# sortledton.raw-access-bfs gcc             dota-league    0 days 00:00:00 0                56                bfs        0.372284
#                                           graph500-22    0 days 00:00:00 0                56                bfs        0.649253
#                                           graph500-24    0 days 00:00:00 0                56                bfs        0.595132
# teseo-lcc-dv.12b          gcc             com-friendster 0 days 00:00:00 0                56                bfs        0.290316
#                                                                                                             wcc        0.221898
#                                           dota-league    0 days 00:00:00 0                56                bfs        0.694200
#                                           graph500-22    0 days 00:00:00 0                56                bfs        0.164334
#                                           graph500-24    0 days 00:00:00 0                56                bfs        0.162963
#                                                                                                             wcc        0.132072
#                                           graph500-26    0 days 00:00:00 0                56                bfs        0.270372
# teseo-lcc.12              gcc             com-friendster 0 days 00:00:00 0                56                bfs        0.213880
#                                           dota-league    0 days 00:00:00 0                56                bfs        0.660541
#                                           graph500-22    0 days 00:00:00 0                56                bfs        0.286489
#                                           graph500-24    0 days 00:00:00 0                56                bfs        0.170301
#                                           graph500-26    0 days 00:00:00 0                56                bfs        0.223514
#                                                                                                             wcc        0.107299
#                                           uniform-24     0 days 00:00:00 0                56                bfs        0.194369

# %%
low_count = data.query("count < 5").copy()
low_count = low_count.query("(library == 'llama8-ref' and build_frequency != '00:00:00') or library != 'llama8-ref'")
low_count = low_count.query("num_threads_write == 0 or num_threads_write == 56")
low_count = low_count.query("library != 'sortledton'")
low_count = low_count.query("library != 'sortledton.1'")
low_count
# Out:
#                                                                                                                             completion_time  \
# library                        compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3                           gcc             com-friendster 0 days          0                0                 bfs               1.027292
#                                                                                                                  cdlp            160.783570
#                                                                                                                  lcc             835.651810
#                                                                                                                  pagerank         31.602786
#                                                                                                                  sssp             43.221247
#                                                                                                                  wcc              10.248647
#                                                dota-league    0 days          0                0                 bfs               0.000805
#                                                                                                                  cdlp              1.148272
#                                                                                                                  lcc             363.353080
#                                                                                                                  pagerank          0.137712
#                                                                                                                  sssp              0.402430
#                                                                                                                  wcc               0.029459
#                                                graph500-22    0 days          0                0                 bfs               0.036871
#                                                                                                                  cdlp              8.128233
#                                                                                                                  lcc             306.267269
#                                                                                                                  pagerank          0.409062
#                                                                                                                  sssp              0.861648
#                                                                                                                  wcc               0.158084
#                                                graph500-24    0 days          0                0                 bfs               0.137484
#                                                                                                                  cdlp             33.922899
#                                                                                                                  lcc            2236.280409
#                                                                                                                  pagerank          2.724284
#                                                                                                                  sssp              6.828722
#                                                                                                                  wcc               0.939615
#                                                graph500-26    0 days          0                0                 bfs               0.498458
#                                                                                                                  cdlp             70.469243
#                                                                                                                  lcc                    NaN
#                                                                                                                  pagerank         15.265612
#                                                                                                                  sssp             31.582371
#                                                                                                                  wcc               4.959747
#                                                uniform-24     0 days          0                0                 bfs               0.147745
#                                                                                                                  cdlp             41.624740
#                                                                                                                  lcc              21.949081
#                                                                                                                  pagerank          3.410902
#                                                                                                                  sssp              7.146886
#                                                                                                                  wcc               1.183984
#                                                uniform-26     0 days          0                0                 bfs               0.572139
#                                                                                                                  cdlp            175.569887
#                                                                                                                  lcc              92.364151
#                                                                                                                  pagerank         18.648990
#                                                                                                                  sssp             36.968563
#                                                                                                                  wcc               6.251525
# csr3-lcc                       gcc             com-friendster 0 days          0                0                 bfs               0.987290
#                                                                                                                  cdlp            296.952842
#                                                                                                                  lcc              67.071760
#                                                                                                                  pagerank         31.766556
#                                                                                                                  sssp             53.552172
#                                                                                                                  wcc              10.134346
#                                                graph500-26    0 days          0                0                 bfs               0.501221
#                                                                                                                  cdlp            104.740893
#                                                                                                                  lcc             569.605217
#                                                                                                                  pagerank         15.323130
#                                                                                                                  sssp             32.456623
#                                                                                                                  wcc               4.929197
#                                                uniform-26     0 days          0                0                 bfs               0.566363
#                                                                                                                  cdlp             98.890649
#                                                                                                                  lcc              13.866267
#                                                                                                                  pagerank         18.633433
#                                                                                                                  sssp             37.459210
#                                                                                                                  wcc               6.191338
# mb-csr.8                       gcc             com-friendster 0 days          0                56                bfs               1.125382
#                                                                                                                  cdlp            227.241485
#                                                                                                                  lcc              59.470150
#                                                                                                                  pagerank         30.603569
#                                                                                                                  sssp             49.037404
#                                                                                                                  wcc              16.095385
#                                                dota-league    0 days          0                56                bfs               0.000776
#                                                                                                                  cdlp              1.107514
#                                                                                                                  lcc              49.816105
#                                                                                                                  pagerank          0.140827
#                                                                                                                  sssp              0.404890
#                                                                                                                  wcc               0.029735
#                                                graph500-22    0 days          0                56                bfs               0.037814
#                                                                                                                  cdlp              3.703384
#                                                                                                                  lcc               8.417857
#                                                                                                                  pagerank          0.337325
#                                                                                                                  sssp              0.826469
#                                                                                                                  wcc               0.118526
#                                                graph500-24    0 days          0                56                bfs               0.139064
#                                                                                                                  cdlp             16.663601
#                                                                                                                  lcc              51.627964
#                                                                                                                  pagerank          1.786068
#                                                                                                                  sssp              4.717334
#                                                                                                                  wcc               0.576570
#                                                graph500-26    0 days          0                56                bfs               0.514324
#                                                                                                                  cdlp            119.647970
#                                                                                                                  lcc             309.646945
#                                                                                                                  pagerank         10.626454
#                                                                                                                  sssp             29.054993
#                                                                                                                  wcc               3.006076
#                                                uniform-24     0 days          0                56                bfs               0.152608
#                                                                                                                  cdlp             40.478046
#                                                                                                                  lcc               3.251787
#                                                                                                                  pagerank          3.344918
#                                                                                                                  sssp              9.652527
#                                                                                                                  wcc               1.012159
#                                                uniform-26     0 days          0                56                bfs               0.563581
#                                                                                                                  cdlp            132.497073
#                                                                                                                  lcc              14.869173
#                                                                                                                  pagerank         18.527266
#                                                                                                                  sssp             46.767923
#                                                                                                                  wcc               7.454135
# sortledton.lock-free-analytics gcc             dota-league    0 days          0                56                bfs               0.004545
#                                                                                                                  pagerank          0.141100
#                                                                                                                  wcc               0.028508
#                                                graph500-22    0 days          0                56                bfs               0.133700
#                                                                                                                  pagerank          0.448956
#                                                                                                                  wcc               0.147847
#                                                graph500-24    0 days          0                56                bfs               0.543475
#                                                                                                                  pagerank          2.352570
#                                                                                                                  wcc               0.667280
#                                                graph500-26    0 days          0                56                bfs               2.109433
#                                                                                                                  pagerank         11.931019
#                                                                                                                  wcc               3.269397
#                                                uniform-24     0 days          0                56                bfs               0.598759
#                                                                                                                  pagerank          4.052745
#                                                                                                                  wcc               1.064632
# sortledton.raw-access-bfs      gcc             graph500-24    0 days          0                56                bfs               0.833700
#                                                                                                                  pagerank          2.301452
#                                                                                                                  wcc               0.653915
# stinger7-ref                   gcc             graph500-24    0 days          0                56                lcc                    NaN
# teseo-lcc.12                   gcc             graph500-26    0 days          0                56                lcc                    NaN
#
#                                                                                                                             count  \
# library                        compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3                           gcc             com-friendster 0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                dota-league    0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                graph500-22    0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                graph500-24    0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                graph500-26    0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            0
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                uniform-24     0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
#                                                uniform-26     0 days          0                0                 bfs            1
#                                                                                                                  cdlp           1
#                                                                                                                  lcc            1
#                                                                                                                  pagerank       1
#                                                                                                                  sssp           1
#                                                                                                                  wcc            1
# csr3-lcc                       gcc             com-friendster 0 days          0                0                 bfs            4
#                                                                                                                  cdlp           4
#                                                                                                                  lcc            4
#                                                                                                                  pagerank       4
#                                                                                                                  sssp           4
#                                                                                                                  wcc            4
#                                                graph500-26    0 days          0                0                 bfs            4
#                                                                                                                  cdlp           4
#                                                                                                                  lcc            4
#                                                                                                                  pagerank       4
#                                                                                                                  sssp           4
#                                                                                                                  wcc            4
#                                                uniform-26     0 days          0                0                 bfs            3
#                                                                                                                  cdlp           3
#                                                                                                                  lcc            3
#                                                                                                                  pagerank       3
#                                                                                                                  sssp           3
#                                                                                                                  wcc            3
# mb-csr.8                       gcc             com-friendster 0 days          0                56                bfs            2
#                                                                                                                  cdlp           2
#                                                                                                                  lcc            2
#                                                                                                                  pagerank       2
#                                                                                                                  sssp           2
#                                                                                                                  wcc            2
#                                                dota-league    0 days          0                56                bfs            2
#                                                                                                                  cdlp           2
#                                                                                                                  lcc            2
#                                                                                                                  pagerank       2
#                                                                                                                  sssp           2
#                                                                                                                  wcc            2
#                                                graph500-22    0 days          0                56                bfs            3
#                                                                                                                  cdlp           3
#                                                                                                                  lcc            3
#                                                                                                                  pagerank       3
#                                                                                                                  sssp           3
#                                                                                                                  wcc            3
#                                                graph500-24    0 days          0                56                bfs            3
#                                                                                                                  cdlp           3
#                                                                                                                  lcc            3
#                                                                                                                  pagerank       3
#                                                                                                                  sssp           3
#                                                                                                                  wcc            3
#                                                graph500-26    0 days          0                56                bfs            2
#                                                                                                                  cdlp           2
#                                                                                                                  lcc            2
#                                                                                                                  pagerank       2
#                                                                                                                  sssp           2
#                                                                                                                  wcc            2
#                                                uniform-24     0 days          0                56                bfs            3
#                                                                                                                  cdlp           3
#                                                                                                                  lcc            3
#                                                                                                                  pagerank       3
#                                                                                                                  sssp           3
#                                                                                                                  wcc            3
#                                                uniform-26     0 days          0                56                bfs            2
#                                                                                                                  cdlp           2
#                                                                                                                  lcc            2
#                                                                                                                  pagerank       2
#                                                                                                                  sssp           2
#                                                                                                                  wcc            2
# sortledton.lock-free-analytics gcc             dota-league    0 days          0                56                bfs            1
#                                                                                                                  pagerank       1
#                                                                                                                  wcc            1
#                                                graph500-22    0 days          0                56                bfs            1
#                                                                                                                  pagerank       1
#                                                                                                                  wcc            1
#                                                graph500-24    0 days          0                56                bfs            1
#                                                                                                                  pagerank       1
#                                                                                                                  wcc            1
#                                                graph500-26    0 days          0                56                bfs            1
#                                                                                                                  pagerank       1
#                                                                                                                  wcc            1
#                                                uniform-24     0 days          0                56                bfs            1
#                                                                                                                  pagerank       1
#                                                                                                                  wcc            1
# sortledton.raw-access-bfs      gcc             graph500-24    0 days          0                56                bfs            4
#                                                                                                                  pagerank       4
#                                                                                                                  wcc            4
# stinger7-ref                   gcc             graph500-24    0 days          0                56                lcc            0
# teseo-lcc.12                   gcc             graph500-26    0 days          0                56                lcc            0
#
#                                                                                                                                ct_std  \
# library                        compiler_family graph          build_frequency num_threads_read num_threads_write algorithm
# csr3                           gcc             com-friendster 0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                dota-league    0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                graph500-22    0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                graph500-24    0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                graph500-26    0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                uniform-24     0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
#                                                uniform-26     0 days          0                0                 bfs              NaN
#                                                                                                                  cdlp             NaN
#                                                                                                                  lcc              NaN
#                                                                                                                  pagerank         NaN
#                                                                                                                  sssp             NaN
#                                                                                                                  wcc              NaN
# csr3-lcc                       gcc             com-friendster 0 days          0                0                 bfs         0.028363
#                                                                                                                  cdlp       63.934555
#                                                                                                                  lcc         2.747167
#                                                                                                                  pagerank    0.210549
#                                                                                                                  sssp        8.474015
#                                                                                                                  wcc         0.059394
#                                                graph500-26    0 days          0                0                 bfs         0.012295
#                                                                                                                  cdlp       43.767062
#                                                                                                                  lcc        32.060869
#                                                                                                                  pagerank    0.014129
#                                                                                                                  sssp        5.782345
#                                                                                                                  wcc         0.011334
#                                                uniform-26     0 days          0                0                 bfs         0.010902
#                                                                                                                  cdlp       42.525480
#                                                                                                                  lcc         0.017100
#                                                                                                                  pagerank    0.022066
#                                                                                                                  sssp        1.470129
#                                                                                                                  wcc         0.027587
# mb-csr.8                       gcc             com-friendster 0 days          0                56                bfs         0.016293
#                                                                                                                  cdlp       69.266765
#                                                                                                                  lcc         0.074127
#                                                                                                                  pagerank    0.146399
#                                                                                                                  sssp        6.106018
#                                                                                                                  wcc         0.775982
#                                                dota-league    0 days          0                56                bfs         0.000024
#                                                                                                                  cdlp        0.088716
#                                                                                                                  lcc         1.265124
#                                                                                                                  pagerank    0.000115
#                                                                                                                  sssp        0.000548
#                                                                                                                  wcc         0.000394
#                                                graph500-22    0 days          0                56                bfs         0.000496
#                                                                                                                  cdlp        1.356020
#                                                                                                                  lcc         0.096439
#                                                                                                                  pagerank    0.004283
#                                                                                                                  sssp        0.065089
#                                                                                                                  wcc         0.002024
#                                                graph500-24    0 days          0                56                bfs         0.001295
#                                                                                                                  cdlp        5.284524
#                                                                                                                  lcc         0.434541
#                                                                                                                  pagerank    0.017170
#                                                                                                                  sssp        0.118692
#                                                                                                                  wcc         0.011368
#                                                graph500-26    0 days          0                56                bfs         0.006921
#                                                                                                                  cdlp        4.604506
#                                                                                                                  lcc         3.891038
#                                                                                                                  pagerank    0.920955
#                                                                                                                  sssp        1.593804
#                                                                                                                  wcc         0.095281
#                                                uniform-24     0 days          0                56                bfs         0.001842
#                                                                                                                  cdlp        2.451238
#                                                                                                                  lcc         0.043294
#                                                                                                                  pagerank    0.002191
#                                                                                                                  sssp        0.434980
#                                                                                                                  wcc         0.005573
#                                                uniform-26     0 days          0                56                bfs         0.000097
#                                                                                                                  cdlp       48.562832
# ...
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                dota-league    0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                graph500-22    0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                graph500-24    0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                graph500-26    0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                uniform-24     0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
#                                                uniform-26     0 days          0                0                 bfs             NaN
#                                                                                                                  cdlp            NaN
#                                                                                                                  lcc             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  sssp            NaN
#                                                                                                                  wcc             NaN
# csr3-lcc                       gcc             com-friendster 0 days          0                0                 bfs        0.028728
#                                                                                                                  cdlp       0.215302
#                                                                                                                  lcc        0.040959
#                                                                                                                  pagerank   0.006628
#                                                                                                                  sssp       0.158238
#                                                                                                                  wcc        0.005861
#                                                graph500-26    0 days          0                0                 bfs        0.024530
#                                                                                                                  cdlp       0.417860
#                                                                                                                  lcc        0.056286
#                                                                                                                  pagerank   0.000922
#                                                                                                                  sssp       0.178156
#                                                                                                                  wcc        0.002299
#                                                uniform-26     0 days          0                0                 bfs        0.019249
#                                                                                                                  cdlp       0.430025
#                                                                                                                  lcc        0.001233
#                                                                                                                  pagerank   0.001184
#                                                                                                                  sssp       0.039246
#                                                                                                                  wcc        0.004456
# mb-csr.8                       gcc             com-friendster 0 days          0                56                bfs        0.014478
#                                                                                                                  cdlp       0.304816
#                                                                                                                  lcc        0.001246
#                                                                                                                  pagerank   0.004784
#                                                                                                                  sssp       0.124518
#                                                                                                                  wcc        0.048211
#                                                dota-league    0 days          0                56                bfs        0.030981
#                                                                                                                  cdlp       0.080104
#                                                                                                                  lcc        0.025396
#                                                                                                                  pagerank   0.000818
#                                                                                                                  sssp       0.001353
#                                                                                                                  wcc        0.013246
#                                                graph500-22    0 days          0                56                bfs        0.013115
#                                                                                                                  cdlp       0.366157
#                                                                                                                  lcc        0.011456
#                                                                                                                  pagerank   0.012697
#                                                                                                                  sssp       0.078755
#                                                                                                                  wcc        0.017076
#                                                graph500-24    0 days          0                56                bfs        0.009311
#                                                                                                                  cdlp       0.317130
#                                                                                                                  lcc        0.008417
#                                                                                                                  pagerank   0.009613
#                                                                                                                  sssp       0.025161
#                                                                                                                  wcc        0.019717
#                                                graph500-26    0 days          0                56                bfs        0.013457
#                                                                                                                  cdlp       0.038484
#                                                                                                                  lcc        0.012566
#                                                                                                                  pagerank   0.086666
#                                                                                                                  sssp       0.054855
#                                                                                                                  wcc        0.031696
#                                                uniform-24     0 days          0                56                bfs        0.012070
#                                                                                                                  cdlp       0.060557
#                                                                                                                  lcc        0.013314
#                                                                                                                  pagerank   0.000655
#                                                                                                                  sssp       0.045064
#                                                                                                                  wcc        0.005506
#                                                uniform-26     0 days          0                56                bfs        0.000172
#                                                                                                                  cdlp       0.366520
#                                                                                                                  lcc        0.021353
#                                                                                                                  pagerank   0.007364
#                                                                                                                  sssp       0.035452
#                                                                                                                  wcc        0.033546
# sortledton.lock-free-analytics gcc             dota-league    0 days          0                56                bfs             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  wcc             NaN
#                                                graph500-22    0 days          0                56                bfs             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  wcc             NaN
#                                                graph500-24    0 days          0                56                bfs             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  wcc             NaN
#                                                graph500-26    0 days          0                56                bfs             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  wcc             NaN
#                                                uniform-24     0 days          0                56                bfs             NaN
#                                                                                                                  pagerank        NaN
#                                                                                                                  wcc             NaN
# sortledton.raw-access-bfs      gcc             graph500-24    0 days          0                56                bfs        0.595132
#                                                                                                                  pagerank   0.010543
#                                                                                                                  wcc        0.029795
# stinger7-ref                   gcc             graph500-24    0 days          0                56                lcc             NaN
# teseo-lcc.12                   gcc             graph500-26    0 days          0                56                lcc             NaN

# %% [markdown]
# List of available executions:

# %%
data = data.unstack("algorithm")[("completion_time")]
data.index.set_names("compiler", level=1, inplace=True)

fn_join_threads = lambda grp: ", ".join(map(str, grp.unique()))
data.reset_index().groupby(["library", "compiler"]).agg(num_threads_w=("num_threads_write", fn_join_threads), num_threads_r=("num_threads_read", fn_join_threads))
# Out:
#                                         num_threads_w num_threads_r
# library                        compiler
# baseline_v3                    gcc                  1             0
# csr3                           gcc                  0             0
# csr3-lcc                       gcc                  0             0
# csr3-lcc-numa                  gcc                  0             0
# g1_v6-ref-ignore-build         gcc                 20             0
# livegraph3_ro                  gcc                 20             0
# llama8-ref                     gcc                 16             0
# mb-csr.6                       gcc                 56             0
# mb-csr.8                       gcc                 56             0
# sortledton                     gcc                 56             0
# sortledton.1                   gcc                 56             0
# sortledton.2                   gcc                 56             0
# sortledton.3                   gcc                 56             0
# sortledton.lock-free-analytics gcc                 56             0
# sortledton.raw-access-bfs      gcc                 56             0
# stinger7-ref                   gcc                 56             0
# teseo-lcc-dv.12b               gcc                 56             0
# teseo-lcc.12                   gcc                 56             0

# %% [markdown]
# ### CSR

# %%
csr = data.loc[("csr3-lcc", "gcc")].droplevel([1,2,3])
csr["lcc_std"] = data.loc[("csr3", "gcc")].droplevel([1,2,3]).rename(columns = {"lcc": "lcc_std"})["lcc_std"]
csr_numa = data.loc[("csr3-lcc-numa", "gcc")].droplevel([1,2,3])
csr_numa["lcc_std"] = data.loc[("csr3", "gcc")].droplevel([1,2,3]).rename(columns = {"lcc": "lcc_std"})["lcc_std"]
mb_csr = data.loc[("mb-csr.8", "gcc")].droplevel([1,2,3])
mb_csr["lcc_std"] = data.loc[("csr3", "gcc")].droplevel([1,2,3]).rename(columns = {"lcc": "lcc_std"})["lcc_std"]
min_csr = mb_csr.combine(csr_numa, np.minimum)
csr = csr[["bfs", "cdlp", "lcc_std", "lcc", "pagerank", "sssp", "wcc"]] # reoder the columns
csr = pd.concat([csr, csr_numa, mb_csr, min_csr], names=["library"], keys=["csr", "csr_numa", "mb_csr", "min_csr"]) # prepend the key `csr`

min_csr
# Out:
# algorithm            bfs        cdlp         lcc   pagerank       sssp  \
# graph
# com-friendster  0.970899  177.237292   59.470150  30.603569  49.037404
# dota-league     0.000727    1.107514   49.816105   0.105036   0.245215
# graph500-22     0.033258    3.703384    8.417857   0.337325   0.739230
# graph500-24     0.131544   14.926092   51.627964   1.786068   4.717334
# graph500-26     0.480766  119.647970  309.646945  10.626454  26.432848
# uniform-24      0.148202   23.132612    2.816906   3.309615   6.443192
# uniform-26      0.518993  132.497073   13.111546  18.350899  34.104711
#
# algorithm             wcc      lcc_std
# graph
# com-friendster  10.068403   835.651810
# dota-league      0.023842   363.353080
# graph500-22      0.118526   306.267269
# graph500-24      0.576570  2236.280409
# graph500-26      3.006076          NaN
# uniform-24       1.012159    21.949081
# uniform-26       6.210624    92.364151

# %%
mb_csr
# Out:
# algorithm            bfs        cdlp         lcc   pagerank       sssp  \
# graph
# com-friendster  1.125382  227.241485   59.470150  30.603569  49.037404
# dota-league     0.000776    1.107514   49.816105   0.140827   0.404890
# graph500-22     0.037814    3.703384    8.417857   0.337325   0.826469
# graph500-24     0.139064   16.663601   51.627964   1.786068   4.717334
# graph500-26     0.514324  119.647970  309.646945  10.626454  29.054993
# uniform-24      0.152608   40.478046    3.251787   3.344918   9.652527
# uniform-26      0.563581  132.497073   14.869173  18.527266  46.767923
#
# algorithm             wcc      lcc_std
# graph
# com-friendster  16.095385   835.651810
# dota-league      0.029735   363.353080
# graph500-22      0.118526   306.267269
# graph500-24      0.576570  2236.280409
# graph500-26      3.006076          NaN
# uniform-24       1.012159    21.949081
# uniform-26       7.454135    92.364151

# %%
compare = mb_csr / csr_numa
compare
# Out:
# algorithm            bfs      cdlp       lcc  pagerank      sssp       wcc  \
# graph
# com-friendster  1.159113  1.282131  0.990628  0.980019  0.824966  1.598604
# dota-league     1.067400  0.945277  0.928568  1.340745  1.651161  1.247148
# graph500-22     1.136990  0.455957  0.705525  0.849108  1.118013  0.769330
# graph500-24     1.057167  1.116407  0.716198  0.664393  0.977228  0.620624
# graph500-26     1.069801  0.848915  0.647426  0.699060  1.099200  0.608095
# uniform-24      1.029730  1.749826  1.154383  1.010667  1.498097  0.869142
# uniform-26      1.085913  0.735411  1.134052  1.009611  1.371304  1.200223
#
# algorithm       lcc_std
# graph
# com-friendster      1.0
# dota-league         1.0
# graph500-22         1.0
# graph500-24         1.0
# graph500-26         NaN
# uniform-24          1.0
# uniform-26          1.0

# %% [markdown]
# ### Other systems

# %%
stinger = pd.concat( [
    data.loc[("stinger7-ref", "gcc")].droplevel([1, 2, 3])
], names=["library"], keys=["stinger"])
llama = pd.concat( [
    data.loc[("llama8-ref", "gcc", slice(None), "00:00:10", 0, 16)].droplevel([0, 1, 3, 4, 5]) # dynamic scheduling in OpenMP
], names=["library"], keys=["llama"] )
graphone = pd.concat( [
   data.loc[("g1_v6-ref-ignore-build", "gcc", slice(None), slice(None), 0, 20)].droplevel([0, 1, 3, 4, 5])
], names=["library"], keys=["graphone"] )
livegraph = pd.concat( [
    data.loc[("livegraph3_ro", "gcc", slice(None), slice(None), slice(None), 20)].droplevel([0, 1, 3, 4, 5])
], names=["library"], keys=["livegraph"] )
competitors = pd.concat([stinger,llama,graphone, livegraph])
#competitors = pd.concat([stinger]).rename(columns = {"lcc": "lcc_std"})

# %% [markdown]
# ### Teseo

# %%
teseo_lcc = data.loc[("teseo-lcc.12", "gcc")].droplevel([1,2,3])
teseo_dv_lcc = data.loc[("teseo-lcc-dv.12b", "gcc")].droplevel([1,2,3])
teseo_lcc["lcc_std"] = np.NaN
teseo_dv_lcc["lcc_std"] = np.NaN

#teseo_std = data.loc[("teseo.12", "gcc")].droplevel([1,2,3]).rename(columns={"lcc": "lcc_std"})
#teseo_std_dv = data.loc[("teseo-dv.12b", "gcc")].droplevel([1,2,3]).rename(columns={"lcc": "lcc_std"})
teseo_logical = pd.concat([ pd.concat([teseo_lcc], axis=1 ) ], names=["library"], keys=["teseo_logical"])
teseo_real = pd.concat([ pd.concat([teseo_dv_lcc], axis=1 ) ], names=["library"], keys=["teseo_real"])

# %% [markdown]
# ### Sortledton

# %%
sortledton3 = data.loc[("sortledton.3", "gcc")].droplevel([1,2,3])
sortledton2 = data.loc[("sortledton.2", "gcc")].droplevel([1,2,3])
sortledton1 = data.loc[("sortledton.1", "gcc")].droplevel([1,2,3])

sortledton = pd.concat([ pd.concat([sortledton3], axis=1 ) ], names=["library"], keys=["sortledton"])
sortledton
# Out:
# algorithm                       bfs        cdlp         lcc   pagerank  \
# library    graph
# sortledton com-friendster  5.053727  260.627118   63.085961  34.759500
#            dota-league     0.001022    1.170734   49.754592   0.127522
#            graph500-22     0.044506    7.326248    8.387854   0.447248
#            graph500-24     0.161151   22.552226   47.786827   2.238029
#            graph500-26     0.598947  149.688249  276.867575  11.900861
#            uniform-24      0.171751   43.936870    3.748761   4.021060
#            uniform-26      0.633141  173.083578   15.913968  20.835272
#
# algorithm                       sssp        wcc
# library    graph
# sortledton com-friendster  49.860027  17.143457
#            dota-league      0.277204   0.027643
#            graph500-22      0.824945   0.137254
#            graph500-24      3.828428   0.629947
#            graph500-26     24.281894   3.098358
#            uniform-24       8.303376   1.061033
#            uniform-26      43.973580   5.534944

# %%
sortledton3
# Out:
# algorithm            bfs        cdlp         lcc   pagerank       sssp  \
# graph
# com-friendster  5.053727  260.627118   63.085961  34.759500  49.860027
# dota-league     0.001022    1.170734   49.754592   0.127522   0.277204
# graph500-22     0.044506    7.326248    8.387854   0.447248   0.824945
# graph500-24     0.161151   22.552226   47.786827   2.238029   3.828428
# graph500-26     0.598947  149.688249  276.867575  11.900861  24.281894
# uniform-24      0.171751   43.936870    3.748761   4.021060   8.303376
# uniform-26      0.633141  173.083578   15.913968  20.835272  43.973580
#
# algorithm             wcc
# graph
# com-friendster  17.143457
# dota-league      0.027643
# graph500-22      0.137254
# graph500-24      0.629947
# graph500-26      3.098358
# uniform-24       1.061033
# uniform-26       5.534944

# %%
sortledton1
# Out:
# algorithm            bfs        cdlp          lcc   pagerank       sssp  \
# graph
# com-friendster  3.235775  321.215246   134.895574  34.986696  69.481733
# dota-league     0.003482    1.240770   452.727168   0.128084   0.438770
# graph500-22     0.104128    5.123496    45.341988   0.444678   1.442452
# graph500-24     0.411168   32.897589   223.036627   2.253371   6.687490
# graph500-26     1.518767  146.673093  1257.411068  11.865370  39.225274
# uniform-24      0.423987   41.752513     5.013913   4.055012  11.751173
# uniform-26      1.546263  148.820877    22.097930  20.850237  57.944908
#
# algorithm             wcc
# graph
# com-friendster  17.536508
# dota-league      0.027536
# graph500-22      0.137924
# graph500-24      0.642449
# graph500-26      3.105267
# uniform-24       1.058800
# uniform-26       8.048062

# %% [markdown]
# I verified that this data is not signficantly different from Sortledton.0
#
# Sortledton.2 vs Sortledton.1
#
# LCC is now much faster, mostly due to the use of shared locks. SSSP is a good bit faster due to the use of blocked iterators.
# Pagerank and CDLP show little difference.
# BFS shows little difference, although I tried the same optimizations which put it at one level with a CSR in the microbenchmarks.
#
# I investigate the issue. First, I removed locking from the computation. This did not change anything. I also moved BFS to run after PageRank. No change.

# %% [markdown]
# ### Dataset

# %%
ds = pd.concat([csr, competitors, teseo_logical, teseo_real, sortledton])
ds = pd.concat([ds, pd.concat([ds.query("library != 'min_csr' and library != 'mb_csr' and library != 'csr' and library != 'csr_numa'").groupby(by="graph", axis=0).apply(lambda t: t.min())], names=["library"], keys=["best_excl_csr"])])
ds
# Out:
# algorithm                          bfs        cdlp      lcc_std          lcc  \
# library       graph
# csr           com-friendster  0.987290  296.952842   835.651810    67.071760
#               dota-league     0.000832    1.130815   363.353080    54.222333
#               graph500-22     0.034255    8.039117   306.267269    12.347005
#               graph500-24     0.136920   32.441325  2236.280409    80.472171
#               graph500-26     0.501221  104.740893          NaN   569.605217
#               uniform-24      0.145892   24.325043    21.949081     2.925042
#               uniform-26      0.566363   98.890649    92.364151    13.866267
# csr_numa      com-friendster  0.970899  177.237292   835.651810    60.032766
#               dota-league     0.000727    1.171629   363.353080    53.648330
#               graph500-22     0.033258    8.122214   306.267269    11.931342
#               graph500-24     0.131544   14.926092  2236.280409    72.086112
#               graph500-26     0.480766  140.942144          NaN   478.273912
#               uniform-24      0.148202   23.132612    21.949081     2.816906
#               uniform-26      0.518993  180.167332    92.364151    13.111546
# mb_csr        com-friendster  1.125382  227.241485   835.651810    59.470150
#               dota-league     0.000776    1.107514   363.353080    49.816105
#               graph500-22     0.037814    3.703384   306.267269     8.417857
#               graph500-24     0.139064   16.663601  2236.280409    51.627964
#               graph500-26     0.514324  119.647970          NaN   309.646945
#               uniform-24      0.152608   40.478046    21.949081     3.251787
#               uniform-26      0.563581  132.497073    92.364151    14.869173
# min_csr       com-friendster  0.970899  177.237292   835.651810    59.470150
#               dota-league     0.000727    1.107514   363.353080    49.816105
#               graph500-22     0.033258    3.703384   306.267269     8.417857
#               graph500-24     0.131544   14.926092  2236.280409    51.627964
#               graph500-26     0.480766  119.647970          NaN   309.646945
#               uniform-24      0.148202   23.132612    21.949081     2.816906
#               uniform-26      0.518993  132.497073    92.364151    13.111546
# stinger       dota-league     0.121506    1.538311          NaN  1029.737622
#               graph500-22     0.138942    4.151513          NaN   896.330526
#               graph500-24     0.509728   19.405766          NaN          NaN
#               uniform-24      0.282872   25.052541          NaN    52.990104
# llama         dota-league     0.002966    2.401328          NaN          NaN
#               graph500-22     0.044881    8.249646          NaN          NaN
#               graph500-24     0.165804   30.885655          NaN          NaN
#               uniform-24      0.212838   63.223419          NaN          NaN
# graphone      dota-league     3.315888    4.690717          NaN   556.099816
#               graph500-22     3.372719    9.974392          NaN   484.695291
#               graph500-24     3.666789   31.449167          NaN          NaN
#               graph500-26     5.189803  135.322500          NaN          NaN
#               uniform-24      3.728817   47.025972          NaN    72.123853
#               uniform-26      5.263770  186.268955          NaN   338.458564
# livegraph     com-friendster  8.524041  290.855899          NaN  1428.454927
#               dota-league     0.057192    1.395516          NaN   573.513740
#               graph500-22     0.519948    6.935005          NaN   493.041368
#               graph500-24     2.150392   27.848318          NaN          NaN
#               graph500-26     8.921137  115.255477          NaN          NaN
#               uniform-24      0.804347   42.654666          NaN    38.357464
#               uniform-26      3.155160  174.584802          NaN   166.254569
# teseo_logical com-friendster  1.436367  413.893893          NaN   414.215798
#               dota-league     0.010583    1.629937          NaN    88.541439
#               graph500-22     0.051867    4.900572          NaN    40.954976
#               graph500-24     0.177329   26.544547          NaN   418.622928
#               graph500-26     0.578424  129.991087          NaN          NaN
#               uniform-24      0.141978   40.872463          NaN    12.888284
#               uniform-26      0.534995  185.567835          NaN    64.927984
# teseo_real    com-friendster  0.988311  187.935188          NaN   119.260646
#               dota-league     0.009959    1.087152          NaN    76.705534
#               graph500-22     0.059112    3.383846          NaN    38.659923
#               graph500-24     0.206834   14.897941          NaN   152.408627
#               graph500-26     0.407783   63.237567          NaN   964.866470
#               uniform-24      0.105795   24.430511          NaN     6.379244
#               uniform-26      0.407369  115.792702          NaN    28.582826
# sortledton    com-friendster  5.053727  260.627118          NaN    63.085961
#               dota-league     0.001022    1.170734          NaN    49.754592
#               graph500-22     0.044506    7.326248          NaN     8.387854
#               graph500-24     0.161151   22.552226          NaN    47.786827
#               graph500-26     0.598947  149.688249          NaN   276.867575
#               uniform-24      0.171751   43.936870          NaN     3.748761
#               uniform-26      0.633141  173.083578          NaN    15.913968
# best_excl_csr com-friendster  0.988311  187.935188          NaN    63.085961
#               dota-league     0.001022    1.087152          NaN    49.754592
#               graph500-22     0.044506    3.383846          NaN     8.387854
#               graph500-24     0.161151   14.897941          NaN    47.786827
#               graph500-26     0.407783   63.237567          NaN   276.867575
#               uniform-24      0.105795   24.430511          NaN     3.748761
#               uniform-26      0.407369  115.792702          NaN    15.913968
#
# algorithm                      pagerank        sssp         wcc
# library       graph
# csr           com-friendster  31.766556   53.552172   10.134346
#               dota-league      0.146841    0.428904    0.030136
#               graph500-22      0.409781    0.901464    0.153195
#               graph500-24      2.710109    5.557368    0.923030
#               graph500-26     15.323130   32.456623    4.929197
#               uniform-24       3.424995    7.171131    1.172135
#               uniform-26      18.633433   37.459210    6.191338
# csr_numa      com-friendster  31.227518   59.441738   10.068403
#               dota-league      0.105036    0.245215    0.023842
#               graph500-22      0.397270    0.739230    0.154064
#               graph500-24      2.688269    4.827259    0.929016
#               graph500-26     15.201051   26.432848    4.943431
#               uniform-24       3.309615    6.443192    1.164549
#               uniform-26      18.350899   34.104711    6.210624
# mb_csr        com-friendster  30.603569   49.037404   16.095385
#               dota-league      0.140827    0.404890    0.029735
#               graph500-22      0.337325    0.826469    0.118526
#               graph500-24      1.786068    4.717334    0.576570
#               graph500-26     10.626454   29.054993    3.006076
#               uniform-24       3.344918    9.652527    1.012159
#               uniform-26      18.527266   46.767923    7.454135
# min_csr       com-friendster  30.603569   49.037404   10.068403
#               dota-league      0.105036    0.245215    0.023842
#               graph500-22      0.337325    0.739230    0.118526
#               graph500-24      1.786068    4.717334    0.576570
#               graph500-26     10.626454   26.432848    3.006076
#               uniform-24       3.309615    6.443192    1.012159
#               uniform-26      18.350899   34.104711    6.210624
# stinger       dota-league      0.849597    1.076187    0.182259
#               graph500-22      1.415605    2.004826    0.655496
#               graph500-24      6.750182    9.528691    2.815429
#               uniform-24       8.581540   13.105210    2.433919
# llama         dota-league      0.144010    1.649414    0.035468
#               graph500-22      0.433066    3.452668    0.143550
#               graph500-24      3.275807   25.491201    0.839498
#               uniform-24       7.538110   69.503388    1.725500
# graphone      dota-league      3.743046    3.946425    6.239842
#               graph500-22      4.325693    5.323083   13.924942
#               graph500-24      9.110301   15.668837   64.645621
#               graph500-26     33.641130   72.754567  352.482678
#               uniform-24      11.348139   21.650063   90.251136
#               uniform-26      40.076869   90.544796  539.230175
# livegraph     com-friendster  73.268094  109.375252   30.448113
#               dota-league      0.476036    0.824219    0.090900
#               graph500-22      1.474466    1.952101    0.390946
#               graph500-24      7.009486    8.998111    1.671248
#               graph500-26     34.549801   57.409542    7.407230
#               uniform-24       9.205213   18.121702    2.309004
#               uniform-26      42.051069   90.646664   10.087313
# teseo_logical com-friendster  80.941592  122.339864   47.880822
#               dota-league      0.353308    0.720724    0.083933
#               graph500-22      1.313295    2.708697    0.489557
#               graph500-24      8.371603   14.424026    3.991096
#               graph500-26     40.886425   84.653865   18.733884
#               uniform-24      10.725797   21.805139    2.741380
#               uniform-26      47.252303   99.477393   17.321635
# teseo_real    com-friendster  34.842155   81.968951    7.984816
#               dota-league      0.208064    0.382267    0.036228
#               graph500-22      0.487648    1.296936    0.136692
#               graph500-24      2.366195    5.669479    0.879131
#               graph500-26     12.517220   32.854498    2.952450
#               uniform-24       4.578971   12.117560    1.076128
#               uniform-26      22.844418   61.633499    5.057713
# sortledton    com-friendster  34.759500   49.860027   17.143457
#               dota-league      0.127522    0.277204    0.027643
#               graph500-22      0.447248    0.824945    0.137254
#               graph500-24      2.238029    3.828428    0.629947
#               graph500-26     11.900861   24.281894    3.098358
#               uniform-24       4.021060    8.303376    1.061033
#               uniform-26      20.835272   43.973580    5.534944
# best_excl_csr com-friendster  34.759500   49.860027    7.984816
#               dota-league      0.127522    0.277204    0.027643
#               graph500-22      0.433066    0.824945    0.136692
#               graph500-24      2.238029    3.828428    0.629947
#               graph500-26     11.900861   24.281894    2.952450
#               uniform-24       4.021060    8.303376    1.061033
#               uniform-26      20.835272   43.973580    5.057713

# %% [markdown]
# ## Show Speedups

# %%
speedups = ds.copy()

csr_name = "min_csr"

# LCC speedup compared against sorted baseline
speedups["bfs_speedup"] = speedups["bfs"] / speedups.loc[csr_name]["bfs"]
speedups["cdlp_speedup"] = speedups["cdlp"] / speedups.loc[csr_name]["cdlp"]
speedups["pagerank_speedup"] = speedups["pagerank"] / speedups.loc[csr_name]["pagerank"]
speedups["sssp_speedup"] = speedups["sssp"] / speedups.loc[csr_name]["sssp"]
speedups["wcc_speedup"] = speedups["wcc"] / speedups.loc[csr_name]["wcc"]
speedups["lcc_speedup"] = speedups["lcc"] / speedups.loc[csr_name]["lcc"]



speedups.drop(["bfs", "cdlp", "lcc_std", "lcc", "pagerank", "sssp", "wcc"], axis=1, inplace=True)
speedups
# Out:
# algorithm                     bfs_speedup  cdlp_speedup  pagerank_speedup  \
# library       graph
# csr           com-friendster     1.016882      1.675454          1.038002
#               dota-league        1.144429      1.021039          1.398006
#               graph500-22        1.029978      2.170749          1.214796
#               graph500-24        1.040868      2.173464          1.517360
#               graph500-26        1.042547      0.875409          1.441980
#               uniform-24         0.984413      1.051548          1.034862
#               uniform-26         1.091273      0.746361          1.015396
# csr_numa      com-friendster     1.000000      1.000000          1.020388
#               dota-league        1.000000      1.057891          1.000000
#               graph500-22        1.000000      2.193187          1.177707
#               graph500-24        1.000000      1.000000          1.505133
#               graph500-26        1.000000      1.177974          1.430491
#               uniform-24         1.000000      1.000000          1.000000
#               uniform-26         1.000000      1.359783          1.000000
# mb_csr        com-friendster     1.159113      1.282131          1.000000
#               dota-league        1.067400      1.000000          1.340745
#               graph500-22        1.136990      1.000000          1.000000
#               graph500-24        1.057167      1.116407          1.000000
#               graph500-26        1.069801      1.000000          1.000000
#               uniform-24         1.029730      1.749826          1.010667
#               uniform-26         1.085913      1.000000          1.009611
# min_csr       com-friendster     1.000000      1.000000          1.000000
#               dota-league        1.000000      1.000000          1.000000
#               graph500-22        1.000000      1.000000          1.000000
#               graph500-24        1.000000      1.000000          1.000000
#               graph500-26        1.000000      1.000000          1.000000
#               uniform-24         1.000000      1.000000          1.000000
#               uniform-26         1.000000      1.000000          1.000000
# stinger       dota-league      167.133425      1.388977          8.088627
#               graph500-22        4.177702      1.121005          4.196561
#               graph500-24        3.874962      1.300124          3.779353
#               uniform-24         1.908692      1.082997          2.592912
# llama         dota-league        4.079092      2.168216          1.371049
#               graph500-22        1.349480      2.227597          1.283824
#               graph500-24        1.260445      2.069239          1.834089
#               uniform-24         1.436134      2.733086          2.277640
# graphone      dota-league     4561.056396      4.235359         35.635839
#               graph500-22      101.410758      2.693318         12.823517
#               graph500-24       27.875000      2.106993          5.100758
#               graph500-26       10.794863      1.131005          3.165791
#               uniform-24        25.160369      2.032886          3.428840
#               uniform-26        10.142276      1.405834          2.183919
# livegraph     com-friendster     8.779534      1.641054          2.394103
#               dota-league       78.668501      1.260044          4.532122
#               graph500-22       15.633772      1.872613          4.371055
#               graph500-24       16.347321      1.865747          3.924535
#               graph500-26       18.556090      0.963288          3.251301
#               uniform-24         5.427369      1.843919          2.781355
#               uniform-26         6.079388      1.317650          2.291499
# teseo_logical com-friendster     1.479420      2.335253          2.644842
#               dota-league       14.557084      1.471708          3.363685
#               graph500-22        1.559535      1.323269          3.893263
#               graph500-24        1.348058      1.778399          4.687169
#               graph500-26        1.203130      1.086446          3.847608
#               uniform-24         0.958003      1.766876          3.240799
#               uniform-26         1.030833      1.400543          2.574931
# teseo_real    com-friendster     1.017934      1.060359          1.138500
#               dota-league       13.698762      0.981615          1.980888
#               graph500-22        1.777377      0.913717          1.445633
#               graph500-24        1.572356      0.998114          1.324807
#               graph500-26        0.848194      0.528530          1.177930
#               uniform-24         0.713857      1.056107          1.383536
#               uniform-26         0.784922      0.873926          1.244866
# sortledton    com-friendster     5.205204      1.470498          1.135799
#               dota-league        1.405777      1.057083          1.214074
#               graph500-22        1.338204      1.978258          1.325867
#               graph500-24        1.225073      1.510926          1.253048
#               graph500-26        1.245818      1.251072          1.119928
#               uniform-24         1.158895      1.899348          1.214963
#               uniform-26         1.219941      1.306320          1.135382
# best_excl_csr com-friendster     1.017934      1.060359          1.135799
#               dota-league        1.405777      0.981615          1.214074
#               graph500-22        1.338204      0.913717          1.283824
#               graph500-24        1.225073      0.998114          1.253048
#               graph500-26        0.848194      0.528530          1.119928
#               uniform-24         0.713857      1.056107          1.214963
#               uniform-26         0.784922      0.873926          1.135382
#
# algorithm                     sssp_speedup  wcc_speedup  lcc_speedup
# library       graph
# csr           com-friendster      1.092068     1.006550     1.127822
#               dota-league         1.749094     1.263988     1.088450
#               graph500-22         1.219463     1.292501     1.466763
#               graph500-24         1.178074     1.600898     1.558693
#               graph500-26         1.227890     1.639745     1.839531
#               uniform-24          1.112978     1.158054     1.038388
#               uniform-26          1.098359     0.996895     1.057562
# csr_numa      com-friendster      1.212171     1.000000     1.009460
#               dota-league         1.000000     1.000000     1.076927
#               graph500-22         1.000000     1.299833     1.417385
#               graph500-24         1.023302     1.611281     1.396261
#               graph500-26         1.000000     1.644480     1.544578
#               uniform-24          1.000000     1.150559     1.000000
#               uniform-26          1.000000     1.000000     1.000000
# mb_csr        com-friendster      1.000000     1.598604     1.000000
#               dota-league         1.651161     1.247148     1.000000
#               graph500-22         1.118013     1.000000     1.000000
#               graph500-24         1.000000     1.000000     1.000000
#               graph500-26         1.099200     1.000000     1.000000
#               uniform-24          1.498097     1.000000     1.154383
#               uniform-26          1.371304     1.200223     1.134052
# min_csr       com-friendster      1.000000     1.000000     1.000000
#               dota-league         1.000000     1.000000     1.000000
#               graph500-22         1.000000     1.000000     1.000000
#               graph500-24         1.000000     1.000000     1.000000
#               graph500-26         1.000000     1.000000     1.000000
#               uniform-24          1.000000     1.000000     1.000000
#               uniform-26          1.000000     1.000000     1.000000
# stinger       dota-league         4.388749     7.644451    20.670777
#               graph500-22         2.712046     5.530398   106.479657
#               graph500-24         2.019931     4.883065          NaN
#               uniform-24          2.033962     2.404680    18.811456
# llama         dota-league         6.726397     1.487627          NaN
#               graph500-22         4.670628     1.211127          NaN
#               graph500-24         5.403730     1.456021          NaN
#               uniform-24         10.787105     1.704772          NaN
# graphone      dota-league        16.093734   261.716383    11.163053
#               graph500-22         7.200848   117.484282    57.579416
#               graph500-24         3.321545   112.121028          NaN
#               graph500-26         2.752430   117.256742          NaN
#               uniform-24          3.360146    89.166955    25.603926
#               uniform-26          2.654906    86.823832    25.813780
# livegraph     com-friendster      2.230445     3.024125    24.019696
#               dota-league         3.361210     3.812600    11.512617
#               graph500-22         2.640722     3.298399    58.570889
#               graph500-24         1.907457     2.898604          NaN
#               graph500-26         2.171901     2.464086          NaN
#               uniform-24          2.812535     2.281266    13.616878
#               uniform-26          2.657893     1.624203    12.680013
# teseo_logical com-friendster      2.494827     4.755553     6.965104
#               dota-league         2.939151     3.520384     1.777366
#               graph500-22         3.664214     4.130376     4.865250
#               graph500-24         3.057665     6.922136     8.108453
#               graph500-26         3.202601     6.232006          NaN
#               uniform-24          3.384214     2.708448     4.575333
#               uniform-26          2.916823     2.789033     4.951970
# teseo_real    com-friendster      1.671560     0.793057     2.005387
#               dota-league         1.558907     1.519503     1.539774
#               graph500-22         1.754442     1.153270     4.592609
#               graph500-24         1.201840     1.524760     2.952056
#               graph500-26         1.242942     0.982161     3.116021
#               uniform-24          1.880677     1.063201     2.264628
#               uniform-26          1.807184     0.814365     2.179974
# sortledton    com-friendster      1.016775     1.702699     1.060800
#               dota-league         1.130453     1.159425     0.998765
#               graph500-22         1.115952     1.158008     0.996436
#               graph500-24         0.811566     1.092578     0.925600
#               graph500-26         0.918626     1.030698     0.894140
#               uniform-24          1.288705     1.048286     1.330808
#               uniform-26          1.289370     0.891206     1.213737
# best_excl_csr com-friendster      1.016775     0.793057     1.060800
#               dota-league         1.130453     1.159425     0.998765
#               graph500-22         1.115952     1.153270     0.996436
#               graph500-24         0.811566     1.092578     0.925600
#               graph500-26         0.918626     0.982161     0.894140
#               uniform-24          1.288705     1.048286     1.330808
#               uniform-26          1.289370     0.814365     1.213737

# %%
from scipy import stats
libraries = ["livegraph", "graphone", "teseo_real", "sortledton", "teseo_logical", "llama", "stinger"]
s = speedups.copy()
#summary.drop("csr", inplace=True)
#summary.drop("csr_numa", inplace=True)
#summary.drop("min_csr", inplace=True)
#summary.drop("mb_csr", inplace=True)
#summary.drop("best_excl_csr", inplace=True)
summary = {}
for l in libraries:
    t = stats.gmean(s.loc[l].fillna(10))
    summary[l] = stats.gmean(t)
#summary = summary.gmean(axis=1)

libraries_speedup_summary = {}
#for l in libraries:
    
sortledton = speedups.loc["sortledton"]

me = sortledton.mean()
ma = sortledton.max()
me.mean()
me
ma
summary
# Out:
# {'livegraph': 4.414500038636615,
#  'graphone': 14.019501436448508,
#  'teseo_real': 1.4130237091615692,
#  'sortledton': 1.2292363626486893,
#  'teseo_logical': 2.9280672321230554,
#  'llama': 2.9327467800786935,
#  'stinger': 4.906304557042812}

# %% [markdown]
# ## We summarize the data
#
# There is nothing too exciting in uniform graphs. We drop them.
#
# We check per dataset if the graph500 scale factor makes a huge difference.
#
# * Livegraph: no
# * Stinger: no but we cannot load grah500-26 and timeout for LCC on 24
# * Graphone: BFS, Pagerank and WCC see less slowdown for big graph datasets
# * Sortledton: we see varying speedup for CDLP and SSSP. A slight tedence to less slowdown on bigger graphs
# * Teseo: lcc, pagerank and wcc are much worse for scale factor 24
# * Teseor real: Tendence to less slow down on bigger graphs
# * LLama: no difference
#
# Generally, slow down improves for bigger scale factors. Teseo has a weak spot for scale factor 24.
#
# We remove Graph500-22.
#
# We now compare Friendster with Graph500-26 for each system:
#
# * Sortledton has issues with BFS on friendster
# * Teseo logical: wcc, pagerank and sssp have larger slow downs on graph500-26
# * Teseo real: we do not have data for friendster yet
# * Livegraph: better slow downs on Friendster for all algorithms, most prounounced for BFS
# * Graphone: cannot load friendster
# * Llama: cannot load either
# * Stinger: cannot load either graph
#
# We drop Graph500-26, because there is nothing new to learn over Graph500-24 if Friendster is presented.
#
# We have three graphs to present dota, friendster and graph500-24.
# These represent three different sizes, real and generated graphs, weak points of Sorltedton and Teseo.
#
# We compare LCC in a different setting as there are two different algorithms making the biggest difference.
#
# We drop the BFS speedup as it is extreme for many systems accross various graphs. We compare this in another graph.
#
# We compare all systems on the three graphs.
# We drop Graphone from the barchar because with it nothing can be seen, it is too slow. This is due to its access by copying into a vector.
# We drop Stinger and Dota league.
#
# We reconsider and show only Graph500-24. We set an ylimit of 8 to cut out WCC on Graphone.

# %%
def format_axes_nospine_left(ax, xscale='linear', yscale='linear'):
    spine_color = 'black'
    for spine in ['top', 'right', 'left']:
        ax.spines[spine].set_visible(False)

    for spine in ['left', 'bottom']:
        ax.spines[spine].set_color(spine_color)
        ax.spines[spine].set_linewidth(0.5)

    ax.xaxis.set_ticks_position('bottom')
    ax.xaxis.set_tick_params(direction='out', color=spine_color)
    
    ax.yaxis.set_tick_params(left=False, right=False, which="major")
    ax.yaxis.grid(b=True, which='both')

    ax.tick_params(axis='both', which='major', pad=0.5)

    return ax

def format_p(p, x_ticks):
    p.set_ylim(0, 9)
    p.set_ylabel("Slowdown")
    p.set_xlabel(None)

    p.set_xticklabels(x_ticks)
    p.legend().remove()
    
    p.axhline(y = 1, color="black", linestyle = '-', linewidth=0.9)

# %%
# Reoder algorithms to fit the order of textual referece
speedups = speedups[["lcc_speedup", "pagerank_speedup", "wcc_speedup", "sssp_speedup", "bfs_speedup", "cdlp_speedup"]]

# %%
OVERFLOW_HEIGHT = 0.825
## Graph500-24
plotting.latexify(columns=1, fig_height=plotting.cm2inch(4.2), font_size=7)
fig, ax = plt.subplots(1, 3, sharey=True)

v = speedups.copy()
v = v.query("graph in 'graph500-24'")
v = v.query("library in ['graphone','sortledton', 'llama', 'teseo_logical', 'teseo_real', 'stinger', 'livegraph']")
v = v.transpose()

colormap=common.set_library_colormap('graph500-24')
sp = ax[0]
p = v.plot.bar(color=colormap, linewidth=0.2, ax=sp, sharey=True, rot=0)

labels = ("LCC \n37m", "PR \n1.77s", "WCC \n0.58s", "SSSP \n4.72s", "BFS \n0.13s", "CDLP \n14.92s",)
format_p(p, labels)
plotting.format_axes(p, categorical_x=True)
sp.set_title("graph500-24", fontsize=8)
sp.tick_params(
            axis='x',          # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False)


sp.text(0.161, OVERFLOW_HEIGHT, "110x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.258, OVERFLOW_HEIGHT, "16x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.228, OVERFLOW_HEIGHT, "28x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)

## Friendster
v = speedups.copy()
v = v.query("graph in 'com-friendster'")
v = v.query("library in ['graphone','sortledton', 'llama', 'teseo_logical', 'teseo_real', 'stinger', 'livegraph']")
v = v.transpose()

colormap=common.set_library_colormap('com-friendster')
sp = ax[1]
p = v.plot.bar(color=colormap, legend=None, linewidth=0.2, ax=sp, sharey=True, rot=0)

labels = ("LCC \n14m", "PR \n30.5s", "WCC \n10.07s", "SSSP \n55.35s", "BFS \n0.97s", "CDLP \n177.23s")
format_p(p, labels)
format_axes_nospine_left(p)
sp.set_title("com-friendster", fontsize=8)
sp.tick_params(
            axis='x',          # changes apply to the x-axis
            which='both',      # both major and minor ticks are affected
            bottom=False,      # ticks along the bottom edge are off
            top=False)
p.set_xlabel("Algorithm and CSR runtime", fontsize=9)

sp.text(0.378, OVERFLOW_HEIGHT, "24x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)

## Dota-League
v = speedups.copy()
v = v.query("graph in ['dota-league']")
v = v.query("library in ['graphone','sortledton', 'llama', 'teseo_logical', 'teseo_real', 'stinger', 'livegraph']")
v = v.transpose()

colormap=common.set_library_colormap('dota-league')
sp = ax[2]
p = v.plot.bar(width=0.7, color=colormap, legend=None, linewidth=0.2, ax=sp, rot=0)

labels = ("LCC \n6m", "PR \n0.1s", "WCC \n0.024s", "SSSP \n0.24s", "BFS \n 0.001s", "CDLP \n 1.17s")
format_p(p, labels)
format_axes_nospine_left(p)

sp.text(0.702, OVERFLOW_HEIGHT, "+11x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.786, OVERFLOW_HEIGHT, "261x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.83, OVERFLOW_HEIGHT, "16x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.741, OVERFLOW_HEIGHT, "36x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.text(0.886, OVERFLOW_HEIGHT, "14x-4561x", fontsize=OVERFLOW_FONT_SIZE, transform=plt.gcf().transFigure)
sp.set_title("dota-league", fontsize=8)

#fig.text(0.4, 0.015, "Algorithm and CSR runtime", fontsize=9)
plt.tight_layout()
plt.savefig(plotting.base_path + "graphalytics-all.png", dpi=400)

# %%
min_csr.query("graph in 'graph500-24'")
# Out:
# algorithm         bfs       cdlp        lcc  pagerank      sssp      wcc  \
# graph
# graph500-24  0.131544  14.926092  51.627964  1.786068  4.717334  0.57657
#
# algorithm        lcc_std
# graph
# graph500-24  2236.280409

# %%
min_csr.query("graph in 'com-friendster'")
# Out:
# algorithm            bfs        cdlp       lcc   pagerank       sssp  \
# graph
# com-friendster  0.970899  177.237292  59.47015  30.603569  49.037404
#
# algorithm             wcc    lcc_std
# graph
# com-friendster  10.068403  835.65181

# %%
min_csr.query("graph in 'dota-league'")
# Out:
# algorithm         bfs      cdlp        lcc  pagerank      sssp       wcc  \
# graph
# dota-league  0.000727  1.107514  49.816105  0.105036  0.245215  0.023842
#
# algorithm      lcc_std
# graph
# dota-league  363.35308

# %%
legend_labels = ["Stinger", "Llama", "GraphOne", "Livegraph", "Teseo logical", "Teseo real", "Sortledton"]
legend = p.legend(ncol=7, borderaxespad=0., labels=legend_labels)
fig  = legend.figure
fig.canvas.draw()
bbox  = legend.get_window_extent().transformed(fig.dpi_scale_trans.inverted())
fig.savefig("../plots/legend.png", dpi=400, bbox_inches=bbox)
